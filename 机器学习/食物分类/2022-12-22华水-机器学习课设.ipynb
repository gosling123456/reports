# %% [markdown]
# # 食物分类实验要求

# %% [markdown]
# 1任务描述
# 数据分为训练集、验证集和测试集，其中，训练集包含1500张食物图像与1500张非食物图像，验证集和测试集均包含500张食物图像和500张非食物图像，建立模型完成食物与非食物图像分类。（难度：简单）
# 2数据集说明
# 数据集包含：
# 	Validation文件夹：验证集
# 	Training文件夹：训练集
# 	Evaluation文件夹：测试集
#
# 数据集下载（427MB）：https://pan.baidu.com/s/1V-TMfpXtBjCT0qGoky2wGQ 提取码：td4f

# %% [markdown]
# # 实验分为两块，机器学习和深度学习

# %% [markdown]
# ## 1.机器学习

# %% [markdown]
# ### 1.1机器学习数据处理

# %%
# 导包
import random
import cv2
import joblib
import numpy
import warnings
from sklearn.metrics import classification_report
warnings.filterwarnings("ignore")
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import os
from tqdm import tqdm

warnings.filterwarnings("ignore")
plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %%
# def mk_dataset(  # 图像数据化
train= '//training'
test= '//evaluation'
validation= '//validation'
# ):
train_path = os.getcwd()+train              # 训练集的绝对路径
test_path  = os.getcwd()+test               # 测试集的绝对路径
vail_path  = os.getcwd()+validation         # 验证集的绝对路径
print(train_path)
print(test_path)
print(vail_path)
# Out:
# D:\Class\Core_course-main\Machine-Learning\Coursr_Design\Experiment2//training
# D:\Class\Core_course-main\Machine-Learning\Coursr_Design\Experiment2//evaluation
# D:\Class\Core_course-main\Machine-Learning\Coursr_Design\Experiment2//validation

# %%
label = {'food': 0, 'non_food': 1}
LABEL = ['food','non_food']
def get_data(path):       ## 参数是图像文件夹的路径
    di = os.listdir(path)
    X = []          # 用作装数据
    Y = []          # 用作装标签
    for i in di:
        for j in list(os.walk(os.path.join(path, i)))[-1][-1]:
            img = cv2.imread(os.path.join(path, i) + '\\' + j)
            img = cv2.resize(img, (24, 24), interpolation=cv2.INTER_CUBIC)
            X.append(img.flatten())
            Y.append(label[i])
    return X,Y

# %%
# 生成并打乱数据和标签
X_train,Y_train = get_data(train_path)      #  训练集数据和标签
X_test,Y_test = get_data(test_path)         #  测试集数据和标签
V_data,V_label = get_data(vail_path)        #  验证集数据和标签
c = list(zip(X_train, Y_train))


random.shuffle(c)
X_train, Y_train = zip(*c)
X_train, Y_train = list(X_train), list(Y_train)

c = list(zip(X_test, Y_test))
random.shuffle(c)
X_test, Y_test = zip(*c)
X_test, Y_test = list(X_test), list(Y_test)

c = list(zip(V_data, V_label))
random.shuffle(c)
V_data, V_label = zip(*c)
V_data, V_label = list(V_data), list(V_label)

Y_train = numpy.array(Y_train)
Y_test = numpy.array(Y_test)
V_label = numpy.array(V_label)
#
print('数据初始化完成！')
#     # return X_train_path, X_test_path, X_train, Y_train, XX_test, Y_test, V_data, V_label, di
# Out:
# 数据初始化完成！

# %%
# """"PCA降维——没用上"""
#     # from sklearn.decomposition import PCA
#     # X = X_train  # 导入数据，维度为65536
#     # pca = PCA(n_components=100)  # 降到100维
#     # pca.fit(X)  # 训练
#     #
#     # X_train = pca.fit_transform(X_train)
#     # XX_test = pca.fit_transform(XX_test)
#     # V_data = pca.fit_transform(V_data)

# %%
## 查看数据集及其标签
print(X_train[0].shape)
for i in range(10):
    plt.subplot(1,10,i+1)
    img =  X_train[i].reshape(24,24,3)  # 重构
    plt.imshow(img[:,:,::-1])           # BGR->RGB
    plt.title(str(Y_train[i]))
    plt.axis('off')                     # 不显示坐标轴
plt.show()
# Out:
# (1728,)

# %% [markdown]
# ### 1.2机器学习模型训练

# %%
models = {
        'Bayes': BernoulliNB(),
        'tree': DecisionTreeClassifier(),
        'KNN': KNeighborsClassifier(),
        'SVM': SVC(kernel='rbf')
    }
epochs = 500
#  定义调参的超参数
C = [i/10 for i in range(1,11)]  # SVM的惩罚系数0.1到1
K = [j for j in range(1,11)]  # KNN的近邻参数1到10
SVM_ACC = {}        # 记录SVM的超参数以及在该超参数训练期间模型最好效果的准确率
KNN_ACC = {}        # 记录KNN的超参数以及在该超参数训练期间模型最好效果的准确率

# %%
for model in models.keys():         # 遍历字典的键，依次来索引模型
    c = list(zip(X_train, Y_train))     # 每一轮训练之前打乱数据顺序
    random.shuffle(c)
    X_train, Y_train = zip(*c)
    X_train, Y_train = list(X_train), list(Y_train)

    Acc = 0                         # 初始正确率，用于迭代
    if model == 'SVM':
        for epoch in range( epochs):
            clf = SVC(C=C[epoch // 50],kernel='rbf').fit(X_train, Y_train)      # C影响因子随着epoch变化
            acc = clf.score(V_data, V_label)                                    # 求当前模型在验证集上的精度
            print('\n')
            print(model+'第%d轮，训练集上准确率：' % epoch, clf.score(X_train, Y_train))
            print(model+'第%d轮，测试集上准确率：' % epoch, clf.score(X_test, Y_test))
            print(model+'第%d轮，验证集上准确率：' % epoch, acc)
            print('')
            if acc > Acc:                                   # 精度出现新高，就保存当前模型，并将该精度赋给Acc继续迭代
                joblib.dump( clf,'./models/' + model + '_best.pt')
                print(model + '准确度新高：', acc,end='\t')
                Acc = acc
            if epoch % 50 == 0:                             # 每50轮换一次影响因子，并记录这50轮中精度最高的模型
                print("惩罚系数C=%.1f在验证集上准确率:" % C[(epoch // 50)], acc)
                SVM_ACC[str(C[epoch // 50])] = acc

    elif model == 'KNN':                                    #同上
        for epoch in range(epochs):
            clf = KNeighborsClassifier(n_neighbors=K[epoch // 50]).fit(X_train, Y_train)
            acc = clf.score(V_data, V_label)
            print('\n')
            print(model + '第%d轮，训练集上准确率：' % epoch, clf.score(X_train, Y_train))
            print(model + '第%d轮，测试集上准确率：' % epoch, clf.score(X_test, Y_test))
            print(model + '第%d轮，验证集上准确率：' % epoch, acc)
            if acc > Acc:
                joblib.dump( clf,'./models/' + model + '_best.pt')
                print(model+'准确度新高：',acc,end='\t')
                Acc = acc
            if epoch % 50 == 0:
                print("邻居数K=%.1f在验证集上准确率:" % K[epoch // 50], acc)
                KNN_ACC[str(K[epoch // 50])] = acc
    else:
        for epoch in range(1,epochs+1):
            clf = models[model].fit(X_train, Y_train)
            acc = round(clf.score(V_data, V_label), 4)
            print('\n')
            print(model + '第%d轮，训练集上准确率：' % epoch, clf.score(X_train, Y_train))
            print(model + '第%d轮，测试集上准确率：' % epoch, clf.score(X_test, Y_test))
            print(model + '第%d轮，验证集上准确率：' % epoch, acc)
            if acc > Acc:
                joblib.dump(clf, './models/' + model + '_best.pt')
                print(model + '准确度新高：', acc,end='\t')
                Acc = acc
    predictions_labels = clf.predict(X_test)
    print(u'预测结果:')
    print(predictions_labels)
    print(u'算法评价:')
    print(classification_report(Y_test, predictions_labels))

plt.subplot(1, 2, 1)
plt.plot([float(i) for i in list(SVM_ACC.keys())], list(SVM_ACC.values()), c='red') # 模型随超参数精度的变化曲线
plt.xlabel('惩罚因子C')
plt.ylabel('验证集上的准确率')
plt.title('SVM调参图')
plt.savefig('SVM.jpg')

plt.subplot(122)
plt.plot([float(i) for i in list(KNN_ACC.keys())], list(KNN_ACC.values()), c='red')  # 模型随超参数精度的变化曲线
plt.xlabel('邻居值K')
plt.ylabel('验证集上的准确率')
plt.title('KNN调参图')
plt.savefig('KNN.jpg')

plt.show()          # 显示出图像，由于我不是在本机上训练的，结果图键Figure_1
#这一趟遍历下来一共运行了2000轮训练，最后保存了4个最好的模型。据观察，这些模型在训练集上的效果只是在80%+，属于是欠拟合的状态，锁着训练轮数的不断增加能达到最终你和的效果
# Out:
# Bayes第1轮，训练集上准确率： 0.5853333333333334
# Bayes第1轮，测试集上准确率： 0.536
# Bayes第1轮，验证集上准确率： 0.561
# Bayes准确度新高： 0.561
#
# Bayes第2轮，训练集上准确率： 0.5853333333333334
# Bayes第2轮，测试集上准确率： 0.536
# Bayes第2轮，验证集上准确率： 0.561
#
#
# Bayes第3轮，训练集上准确率： 0.5853333333333334
# Bayes第3轮，测试集上准确率： 0.536
# Bayes第3轮，验证集上准确率： 0.561
#
#
# Bayes第4轮，训练集上准确率： 0.5853333333333334
# Bayes第4轮，测试集上准确率： 0.536
# Bayes第4轮，验证集上准确率： 0.561
#
#
# Bayes第5轮，训练集上准确率： 0.5853333333333334
# Bayes第5轮，测试集上准确率： 0.536
# Bayes第5轮，验证集上准确率： 0.561
#
#
# Bayes第6轮，训练集上准确率： 0.5853333333333334
# Bayes第6轮，测试集上准确率： 0.536
# Bayes第6轮，验证集上准确率： 0.561
#
#
# Bayes第7轮，训练集上准确率： 0.5853333333333334
# Bayes第7轮，测试集上准确率： 0.536
# Bayes第7轮，验证集上准确率： 0.561
#
#
# Bayes第8轮，训练集上准确率： 0.5853333333333334
# Bayes第8轮，测试集上准确率： 0.536
# Bayes第8轮，验证集上准确率： 0.561
#
#
# Bayes第9轮，训练集上准确率： 0.5853333333333334
# Bayes第9轮，测试集上准确率： 0.536
# Bayes第9轮，验证集上准确率： 0.561
#
#
# Bayes第10轮，训练集上准确率： 0.5853333333333334
# Bayes第10轮，测试集上准确率： 0.536
# Bayes第10轮，验证集上准确率： 0.561
#
#
# Bayes第11轮，训练集上准确率： 0.5853333333333334
# Bayes第11轮，测试集上准确率： 0.536
# Bayes第11轮，验证集上准确率： 0.561
#
#
# Bayes第12轮，训练集上准确率： 0.5853333333333334
# Bayes第12轮，测试集上准确率： 0.536
# Bayes第12轮，验证集上准确率： 0.561
#
#
# Bayes第13轮，训练集上准确率： 0.5853333333333334
# Bayes第13轮，测试集上准确率： 0.536
# Bayes第13轮，验证集上准确率： 0.561
#
#
# Bayes第14轮，训练集上准确率： 0.5853333333333334
# Bayes第14轮，测试集上准确率： 0.536
# Bayes第14轮，验证集上准确率： 0.561
#
#
# Bayes第15轮，训练集上准确率： 0.5853333333333334
# Bayes第15轮，测试集上准确率： 0.536
# Bayes第15轮，验证集上准确率： 0.561
#
#
# Bayes第16轮，训练集上准确率： 0.5853333333333334
# Bayes第16轮，测试集上准确率： 0.536
# Bayes第16轮，验证集上准确率： 0.561
#
#
# Bayes第17轮，训练集上准确率： 0.5853333333333334
# Bayes第17轮，测试集上准确率： 0.536
# Bayes第17轮，验证集上准确率： 0.561
#
#
# Bayes第18轮，训练集上准确率： 0.5853333333333334
# Bayes第18轮，测试集上准确率： 0.536
# Bayes第18轮，验证集上准确率： 0.561
#
#
# Bayes第19轮，训练集上准确率： 0.5853333333333334
# Bayes第19轮，测试集上准确率： 0.536
# Bayes第19轮，验证集上准确率： 0.561
#
#
# Bayes第20轮，训练集上准确率： 0.5853333333333334
# Bayes第20轮，测试集上准确率： 0.536
# Bayes第20轮，验证集上准确率： 0.561
#
#
# Bayes第21轮，训练集上准确率： 0.5853333333333334
# Bayes第21轮，测试集上准确率： 0.536
# Bayes第21轮，验证集上准确率： 0.561
#
#
# Bayes第22轮，训练集上准确率： 0.5853333333333334
# Bayes第22轮，测试集上准确率： 0.536
# Bayes第22轮，验证集上准确率： 0.561
#
#
# Bayes第23轮，训练集上准确率： 0.5853333333333334
# Bayes第23轮，测试集上准确率： 0.536
# Bayes第23轮，验证集上准确率： 0.561
#
#
# Bayes第24轮，训练集上准确率： 0.5853333333333334
# Bayes第24轮，测试集上准确率： 0.536
# Bayes第24轮，验证集上准确率： 0.561
#
#
# Bayes第25轮，训练集上准确率： 0.5853333333333334
# Bayes第25轮，测试集上准确率： 0.536
# Bayes第25轮，验证集上准确率： 0.561
#
#
# Bayes第26轮，训练集上准确率： 0.5853333333333334
# Bayes第26轮，测试集上准确率： 0.536
# Bayes第26轮，验证集上准确率： 0.561
#
#
# Bayes第27轮，训练集上准确率： 0.5853333333333334
# Bayes第27轮，测试集上准确率： 0.536
# Bayes第27轮，验证集上准确率： 0.561
#
#
# Bayes第28轮，训练集上准确率： 0.5853333333333334
# Bayes第28轮，测试集上准确率： 0.536
# Bayes第28轮，验证集上准确率： 0.561
#
#
# Bayes第29轮，训练集上准确率： 0.5853333333333334
# Bayes第29轮，测试集上准确率： 0.536
# Bayes第29轮，验证集上准确率： 0.561
#
#
# Bayes第30轮，训练集上准确率： 0.5853333333333334
# Bayes第30轮，测试集上准确率： 0.536
# Bayes第30轮，验证集上准确率： 0.561
#
#
# Bayes第31轮，训练集上准确率： 0.5853333333333334
# Bayes第31轮，测试集上准确率： 0.536
# Bayes第31轮，验证集上准确率： 0.561
#
#
# Bayes第32轮，训练集上准确率： 0.5853333333333334
# Bayes第32轮，测试集上准确率： 0.536
# Bayes第32轮，验证集上准确率： 0.561
#
#
# Bayes第33轮，训练集上准确率： 0.5853333333333334
# Bayes第33轮，测试集上准确率： 0.536
# Bayes第33轮，验证集上准确率： 0.561
#
#
# Bayes第34轮，训练集上准确率： 0.5853333333333334
# Bayes第34轮，测试集上准确率： 0.536
# Bayes第34轮，验证集上准确率： 0.561
#
#
# Bayes第35轮，训练集上准确率： 0.5853333333333334
# Bayes第35轮，测试集上准确率： 0.536
# Bayes第35轮，验证集上准确率： 0.561
#
#
# Bayes第36轮，训练集上准确率： 0.5853333333333334
# Bayes第36轮，测试集上准确率： 0.536
# Bayes第36轮，验证集上准确率： 0.561
#
#
# Bayes第37轮，训练集上准确率： 0.5853333333333334
# Bayes第37轮，测试集上准确率： 0.536
# Bayes第37轮，验证集上准确率： 0.561
#
#
# Bayes第38轮，训练集上准确率： 0.5853333333333334
# Bayes第38轮，测试集上准确率： 0.536
# Bayes第38轮，验证集上准确率： 0.561
#
#
# Bayes第39轮，训练集上准确率： 0.5853333333333334
# Bayes第39轮，测试集上准确率： 0.536
# Bayes第39轮，验证集上准确率： 0.561
#
#
# Bayes第40轮，训练集上准确率： 0.5853333333333334
# Bayes第40轮，测试集上准确率： 0.536
# Bayes第40轮，验证集上准确率： 0.561
#
#
# Bayes第41轮，训练集上准确率： 0.5853333333333334
# Bayes第41轮，测试集上准确率： 0.536
# Bayes第41轮，验证集上准确率： 0.561
#
#
# Bayes第42轮，训练集上准确率： 0.5853333333333334
# Bayes第42轮，测试集上准确率： 0.536
# Bayes第42轮，验证集上准确率： 0.561
#
#
# Bayes第43轮，训练集上准确率： 0.5853333333333334
# Bayes第43轮，测试集上准确率： 0.536
# Bayes第43轮，验证集上准确率： 0.561
#
#
# Bayes第44轮，训练集上准确率： 0.5853333333333334
# Bayes第44轮，测试集上准确率： 0.536
# Bayes第44轮，验证集上准确率： 0.561
#
#
# Bayes第45轮，训练集上准确率： 0.5853333333333334
# Bayes第45轮，测试集上准确率： 0.536
# Bayes第45轮，验证集上准确率： 0.561
#
#
# Bayes第46轮，训练集上准确率： 0.5853333333333334
# Bayes第46轮，测试集上准确率： 0.536
# Bayes第46轮，验证集上准确率： 0.561
#
#
# Bayes第47轮，训练集上准确率： 0.5853333333333334
# Bayes第47轮，测试集上准确率： 0.536
# Bayes第47轮，验证集上准确率： 0.561
#
#
# Bayes第48轮，训练集上准确率： 0.5853333333333334
# Bayes第48轮，测试集上准确率： 0.536
# Bayes第48轮，验证集上准确率： 0.561
#
#
# Bayes第49轮，训练集上准确率： 0.5853333333333334
# Bayes第49轮，测试集上准确率： 0.536
# Bayes第49轮，验证集上准确率： 0.561
#
#
# Bayes第50轮，训练集上准确率： 0.5853333333333334
# Bayes第50轮，测试集上准确率： 0.536
# Bayes第50轮，验证集上准确率： 0.561
#
#
# Bayes第51轮，训练集上准确率： 0.5853333333333334
# Bayes第51轮，测试集上准确率： 0.536
# Bayes第51轮，验证集上准确率： 0.561
#
#
# Bayes第52轮，训练集上准确率： 0.5853333333333334
# Bayes第52轮，测试集上准确率： 0.536
# Bayes第52轮，验证集上准确率： 0.561
#
#
# Bayes第53轮，训练集上准确率： 0.5853333333333334
# Bayes第53轮，测试集上准确率： 0.536
# Bayes第53轮，验证集上准确率： 0.561
#
#
# Bayes第54轮，训练集上准确率： 0.5853333333333334
# Bayes第54轮，测试集上准确率： 0.536
# Bayes第54轮，验证集上准确率： 0.561
#
#
# Bayes第55轮，训练集上准确率： 0.5853333333333334
# Bayes第55轮，测试集上准确率： 0.536
# Bayes第55轮，验证集上准确率： 0.561
#
#
# Bayes第56轮，训练集上准确率： 0.5853333333333334
# Bayes第56轮，测试集上准确率： 0.536
# Bayes第56轮，验证集上准确率： 0.561
#
#
# Bayes第57轮，训练集上准确率： 0.5853333333333334
# Bayes第57轮，测试集上准确率： 0.536
# Bayes第57轮，验证集上准确率： 0.561
#
#
# Bayes第58轮，训练集上准确率： 0.5853333333333334
# Bayes第58轮，测试集上准确率： 0.536
# Bayes第58轮，验证集上准确率： 0.561
#
#
# Bayes第59轮，训练集上准确率： 0.5853333333333334
# Bayes第59轮，测试集上准确率： 0.536
# Bayes第59轮，验证集上准确率： 0.561
#
#
# Bayes第60轮，训练集上准确率： 0.5853333333333334
# Bayes第60轮，测试集上准确率： 0.536
# Bayes第60轮，验证集上准确率： 0.561
#
#
# Bayes第61轮，训练集上准确率： 0.5853333333333334
# Bayes第61轮，测试集上准确率： 0.536
# Bayes第61轮，验证集上准确率： 0.561
#
#
# Bayes第62轮，训练集上准确率： 0.5853333333333334
# Bayes第62轮，测试集上准确率： 0.536
# Bayes第62轮，验证集上准确率： 0.561
#
#
# Bayes第63轮，训练集上准确率： 0.5853333333333334
# Bayes第63轮，测试集上准确率： 0.536
# Bayes第63轮，验证集上准确率： 0.561
#
#
# Bayes第64轮，训练集上准确率： 0.5853333333333334
# Bayes第64轮，测试集上准确率： 0.536
# Bayes第64轮，验证集上准确率： 0.561
#
#
# Bayes第65轮，训练集上准确率： 0.5853333333333334
# Bayes第65轮，测试集上准确率： 0.536
# Bayes第65轮，验证集上准确率： 0.561
#
#
# Bayes第66轮，训练集上准确率： 0.5853333333333334
# Bayes第66轮，测试集上准确率： 0.536
# Bayes第66轮，验证集上准确率： 0.561
#
#
# Bayes第67轮，训练集上准确率： 0.5853333333333334
# Bayes第67轮，测试集上准确率： 0.536
# Bayes第67轮，验证集上准确率： 0.561
#
#
# Bayes第68轮，训练集上准确率： 0.5853333333333334
# Bayes第68轮，测试集上准确率： 0.536
# Bayes第68轮，验证集上准确率： 0.561
#
#
# Bayes第69轮，训练集上准确率： 0.5853333333333334
# Bayes第69轮，测试集上准确率： 0.536
# Bayes第69轮，验证集上准确率： 0.561
#
#
# Bayes第70轮，训练集上准确率： 0.5853333333333334
# Bayes第70轮，测试集上准确率： 0.536
# Bayes第70轮，验证集上准确率： 0.561
#
#
# Bayes第71轮，训练集上准确率： 0.5853333333333334
# Bayes第71轮，测试集上准确率： 0.536
# Bayes第71轮，验证集上准确率： 0.561
#
#
# Bayes第72轮，训练集上准确率： 0.5853333333333334
# Bayes第72轮，测试集上准确率： 0.536
# Bayes第72轮，验证集上准确率： 0.561
#
#
# Bayes第73轮，训练集上准确率： 0.5853333333333334
# Bayes第73轮，测试集上准确率： 0.536
# Bayes第73轮，验证集上准确率： 0.561
#
#
# Bayes第74轮，训练集上准确率： 0.5853333333333334
# Bayes第74轮，测试集上准确率： 0.536
# Bayes第74轮，验证集上准确率： 0.561
#
#
# Bayes第75轮，训练集上准确率： 0.5853333333333334
# Bayes第75轮，测试集上准确率： 0.536
# Bayes第75轮，验证集上准确率： 0.561
#
#
# Bayes第76轮，训练集上准确率： 0.5853333333333334
# Bayes第76轮，测试集上准确率： 0.536
# Bayes第76轮，验证集上准确率： 0.561
#
#
# Bayes第77轮，训练集上准确率： 0.5853333333333334
# Bayes第77轮，测试集上准确率： 0.536
# Bayes第77轮，验证集上准确率： 0.561
#
#
# Bayes第78轮，训练集上准确率： 0.5853333333333334
# Bayes第78轮，测试集上准确率： 0.536
# Bayes第78轮，验证集上准确率： 0.561
#
#
# Bayes第79轮，训练集上准确率： 0.5853333333333334
# Bayes第79轮，测试集上准确率： 0.536
# Bayes第79轮，验证集上准确率： 0.561
#
#
# Bayes第80轮，训练集上准确率： 0.5853333333333334
# Bayes第80轮，测试集上准确率： 0.536
# Bayes第80轮，验证集上准确率： 0.561
#
#
# Bayes第81轮，训练集上准确率： 0.5853333333333334
# Bayes第81轮，测试集上准确率： 0.536
# Bayes第81轮，验证集上准确率： 0.561
#
#
# Bayes第82轮，训练集上准确率： 0.5853333333333334
# Bayes第82轮，测试集上准确率： 0.536
# Bayes第82轮，验证集上准确率： 0.561
#
#
# Bayes第83轮，训练集上准确率： 0.5853333333333334
# Bayes第83轮，测试集上准确率： 0.536
# Bayes第83轮，验证集上准确率： 0.561
#
#
# Bayes第84轮，训练集上准确率： 0.5853333333333334
# Bayes第84轮，测试集上准确率： 0.536
# Bayes第84轮，验证集上准确率： 0.561
#
#
# Bayes第85轮，训练集上准确率： 0.5853333333333334
# Bayes第85轮，测试集上准确率： 0.536
# Bayes第85轮，验证集上准确率： 0.561
#
#
# Bayes第86轮，训练集上准确率： 0.5853333333333334
# Bayes第86轮，测试集上准确率： 0.536
# Bayes第86轮，验证集上准确率： 0.561
#
#
# Bayes第87轮，训练集上准确率： 0.5853333333333334
# Bayes第87轮，测试集上准确率： 0.536
# Bayes第87轮，验证集上准确率： 0.561
#
#
# Bayes第88轮，训练集上准确率： 0.5853333333333334
# Bayes第88轮，测试集上准确率： 0.536
# Bayes第88轮，验证集上准确率： 0.561
#
#
# Bayes第89轮，训练集上准确率： 0.5853333333333334
# Bayes第89轮，测试集上准确率： 0.536
# Bayes第89轮，验证集上准确率： 0.561
#
#
# Bayes第90轮，训练集上准确率： 0.5853333333333334
# Bayes第90轮，测试集上准确率： 0.536
# Bayes第90轮，验证集上准确率： 0.561
#
#
# Bayes第91轮，训练集上准确率： 0.5853333333333334
# Bayes第91轮，测试集上准确率： 0.536
# Bayes第91轮，验证集上准确率： 0.561
#
#
# Bayes第92轮，训练集上准确率： 0.5853333333333334
# Bayes第92轮，测试集上准确率： 0.536
# Bayes第92轮，验证集上准确率： 0.561
#
#
# Bayes第93轮，训练集上准确率： 0.5853333333333334
# Bayes第93轮，测试集上准确率： 0.536
# Bayes第93轮，验证集上准确率： 0.561
#
#
# Bayes第94轮，训练集上准确率： 0.5853333333333334
# Bayes第94轮，测试集上准确率： 0.536
# Bayes第94轮，验证集上准确率： 0.561
#
#
# Bayes第95轮，训练集上准确率： 0.5853333333333334
# Bayes第95轮，测试集上准确率： 0.536
# Bayes第95轮，验证集上准确率： 0.561
#
#
# Bayes第96轮，训练集上准确率： 0.5853333333333334
# Bayes第96轮，测试集上准确率： 0.536
# Bayes第96轮，验证集上准确率： 0.561
#
#
# Bayes第97轮，训练集上准确率： 0.5853333333333334
# Bayes第97轮，测试集上准确率： 0.536
# Bayes第97轮，验证集上准确率： 0.561
#
#
# Bayes第98轮，训练集上准确率： 0.5853333333333334
# Bayes第98轮，测试集上准确率： 0.536
# Bayes第98轮，验证集上准确率： 0.561
#
#
# Bayes第99轮，训练集上准确率： 0.5853333333333334
# Bayes第99轮，测试集上准确率： 0.536
# Bayes第99轮，验证集上准确率： 0.561
#
#
# Bayes第100轮，训练集上准确率： 0.5853333333333334
# Bayes第100轮，测试集上准确率： 0.536
# Bayes第100轮，验证集上准确率： 0.561
#
#
# Bayes第101轮，训练集上准确率： 0.5853333333333334
# Bayes第101轮，测试集上准确率： 0.536
# Bayes第101轮，验证集上准确率： 0.561
#
#
# Bayes第102轮，训练集上准确率： 0.5853333333333334
# Bayes第102轮，测试集上准确率： 0.536
# Bayes第102轮，验证集上准确率： 0.561
#
#
# Bayes第103轮，训练集上准确率： 0.5853333333333334
# Bayes第103轮，测试集上准确率： 0.536
# Bayes第103轮，验证集上准确率： 0.561
#
#
# Bayes第104轮，训练集上准确率： 0.5853333333333334
# Bayes第104轮，测试集上准确率： 0.536
# Bayes第104轮，验证集上准确率： 0.561
#
#
# Bayes第105轮，训练集上准确率： 0.5853333333333334
# Bayes第105轮，测试集上准确率： 0.536
# Bayes第105轮，验证集上准确率： 0.561
#
#
# Bayes第106轮，训练集上准确率： 0.5853333333333334
# Bayes第106轮，测试集上准确率： 0.536
# Bayes第106轮，验证集上准确率： 0.561
#
#
# Bayes第107轮，训练集上准确率： 0.5853333333333334
# Bayes第107轮，测试集上准确率： 0.536
# Bayes第107轮，验证集上准确率： 0.561
#
#
# Bayes第108轮，训练集上准确率： 0.5853333333333334
# Bayes第108轮，测试集上准确率： 0.536
# Bayes第108轮，验证集上准确率： 0.561
#
#
# Bayes第109轮，训练集上准确率： 0.5853333333333334
# Bayes第109轮，测试集上准确率： 0.536
# Bayes第109轮，验证集上准确率： 0.561
#
#
# Bayes第110轮，训练集上准确率： 0.5853333333333334
# Bayes第110轮，测试集上准确率： 0.536
# Bayes第110轮，验证集上准确率： 0.561
#
#
# Bayes第111轮，训练集上准确率： 0.5853333333333334
# Bayes第111轮，测试集上准确率： 0.536
# Bayes第111轮，验证集上准确率： 0.561
#
#
# Bayes第112轮，训练集上准确率： 0.5853333333333334
# Bayes第112轮，测试集上准确率： 0.536
# Bayes第112轮，验证集上准确率： 0.561
#
#
# Bayes第113轮，训练集上准确率： 0.5853333333333334
# Bayes第113轮，测试集上准确率： 0.536
# Bayes第113轮，验证集上准确率： 0.561
#
#
# Bayes第114轮，训练集上准确率： 0.5853333333333334
# Bayes第114轮，测试集上准确率： 0.536
# Bayes第114轮，验证集上准确率： 0.561
#
#
# Bayes第115轮，训练集上准确率： 0.5853333333333334
# Bayes第115轮，测试集上准确率： 0.536
# Bayes第115轮，验证集上准确率： 0.561
#
#
# Bayes第116轮，训练集上准确率： 0.5853333333333334
# Bayes第116轮，测试集上准确率： 0.536
# Bayes第116轮，验证集上准确率： 0.561
#
#
# Bayes第117轮，训练集上准确率： 0.5853333333333334
# Bayes第117轮，测试集上准确率： 0.536
# Bayes第117轮，验证集上准确率： 0.561
#
#
# Bayes第118轮，训练集上准确率： 0.5853333333333334
# Bayes第118轮，测试集上准确率： 0.536
# Bayes第118轮，验证集上准确率： 0.561
#
#
# Bayes第119轮，训练集上准确率： 0.5853333333333334
# Bayes第119轮，测试集上准确率： 0.536
# Bayes第119轮，验证集上准确率： 0.561
#
#
# Bayes第120轮，训练集上准确率： 0.5853333333333334
# Bayes第120轮，测试集上准确率： 0.536
# Bayes第120轮，验证集上准确率： 0.561
#
#
# Bayes第121轮，训练集上准确率： 0.5853333333333334
# Bayes第121轮，测试集上准确率： 0.536
# Bayes第121轮，验证集上准确率： 0.561
#
#
# Bayes第122轮，训练集上准确率： 0.5853333333333334
# Bayes第122轮，测试集上准确率： 0.536
# Bayes第122轮，验证集上准确率： 0.561
#
#
# Bayes第123轮，训练集上准确率： 0.5853333333333334
# Bayes第123轮，测试集上准确率： 0.536
# Bayes第123轮，验证集上准确率： 0.561
#
#
# Bayes第124轮，训练集上准确率： 0.5853333333333334
# Bayes第124轮，测试集上准确率： 0.536
# Bayes第124轮，验证集上准确率： 0.561
#
#
# Bayes第125轮，训练集上准确率： 0.5853333333333334
# Bayes第125轮，测试集上准确率： 0.536
# Bayes第125轮，验证集上准确率： 0.561
#
#
# Bayes第126轮，训练集上准确率： 0.5853333333333334
# Bayes第126轮，测试集上准确率： 0.536
# Bayes第126轮，验证集上准确率： 0.561
#
#
# Bayes第127轮，训练集上准确率： 0.5853333333333334
# Bayes第127轮，测试集上准确率： 0.536
# Bayes第127轮，验证集上准确率： 0.561
#
#
# Bayes第128轮，训练集上准确率： 0.5853333333333334
# Bayes第128轮，测试集上准确率： 0.536
# Bayes第128轮，验证集上准确率： 0.561
#
#
# Bayes第129轮，训练集上准确率： 0.5853333333333334
# Bayes第129轮，测试集上准确率： 0.536
# Bayes第129轮，验证集上准确率： 0.561
#
#
# Bayes第130轮，训练集上准确率： 0.5853333333333334
# Bayes第130轮，测试集上准确率： 0.536
# Bayes第130轮，验证集上准确率： 0.561
#
#
# Bayes第131轮，训练集上准确率： 0.5853333333333334
# Bayes第131轮，测试集上准确率： 0.536
# Bayes第131轮，验证集上准确率： 0.561
#
#
# Bayes第132轮，训练集上准确率： 0.5853333333333334
# Bayes第132轮，测试集上准确率： 0.536
# Bayes第132轮，验证集上准确率： 0.561
#
#
# Bayes第133轮，训练集上准确率： 0.5853333333333334
# Bayes第133轮，测试集上准确率： 0.536
# Bayes第133轮，验证集上准确率： 0.561
#
#
# Bayes第134轮，训练集上准确率： 0.5853333333333334
# Bayes第134轮，测试集上准确率： 0.536
# Bayes第134轮，验证集上准确率： 0.561
#
#
# Bayes第135轮，训练集上准确率： 0.5853333333333334
# Bayes第135轮，测试集上准确率： 0.536
# Bayes第135轮，验证集上准确率： 0.561
#
#
# Bayes第136轮，训练集上准确率： 0.5853333333333334
# Bayes第136轮，测试集上准确率： 0.536
# Bayes第136轮，验证集上准确率： 0.561
#
#
# Bayes第137轮，训练集上准确率： 0.5853333333333334
# Bayes第137轮，测试集上准确率： 0.536
# Bayes第137轮，验证集上准确率： 0.561
#
#
# Bayes第138轮，训练集上准确率： 0.5853333333333334
# Bayes第138轮，测试集上准确率： 0.536
# Bayes第138轮，验证集上准确率： 0.561
#
#
# Bayes第139轮，训练集上准确率： 0.5853333333333334
# Bayes第139轮，测试集上准确率： 0.536
# Bayes第139轮，验证集上准确率： 0.561
#
#
# Bayes第140轮，训练集上准确率： 0.5853333333333334
# Bayes第140轮，测试集上准确率： 0.536
# Bayes第140轮，验证集上准确率： 0.561
#
#
# Bayes第141轮，训练集上准确率： 0.5853333333333334
# Bayes第141轮，测试集上准确率： 0.536
# Bayes第141轮，验证集上准确率： 0.561
#
#
# Bayes第142轮，训练集上准确率： 0.5853333333333334
# Bayes第142轮，测试集上准确率： 0.536
# Bayes第142轮，验证集上准确率： 0.561
#
#
# Bayes第143轮，训练集上准确率： 0.5853333333333334
# Bayes第143轮，测试集上准确率： 0.536
# Bayes第143轮，验证集上准确率： 0.561
#
#
# Bayes第144轮，训练集上准确率： 0.5853333333333334
# Bayes第144轮，测试集上准确率： 0.536
# Bayes第144轮，验证集上准确率： 0.561
#
#
# Bayes第145轮，训练集上准确率： 0.5853333333333334
# Bayes第145轮，测试集上准确率： 0.536
# Bayes第145轮，验证集上准确率： 0.561
#
#
# Bayes第146轮，训练集上准确率： 0.5853333333333334
# Bayes第146轮，测试集上准确率： 0.536
# Bayes第146轮，验证集上准确率： 0.561
#
#
# Bayes第147轮，训练集上准确率： 0.5853333333333334
# Bayes第147轮，测试集上准确率： 0.536
# Bayes第147轮，验证集上准确率： 0.561
#
#
# Bayes第148轮，训练集上准确率： 0.5853333333333334
# Bayes第148轮，测试集上准确率： 0.536
# Bayes第148轮，验证集上准确率： 0.561
#
#
# Bayes第149轮，训练集上准确率： 0.5853333333333334
# Bayes第149轮，测试集上准确率： 0.536
# Bayes第149轮，验证集上准确率： 0.561
#
#
# Bayes第150轮，训练集上准确率： 0.5853333333333334
# Bayes第150轮，测试集上准确率： 0.536
# Bayes第150轮，验证集上准确率： 0.561
#
#
# Bayes第151轮，训练集上准确率： 0.5853333333333334
# Bayes第151轮，测试集上准确率： 0.536
# Bayes第151轮，验证集上准确率： 0.561
#
#
# Bayes第152轮，训练集上准确率： 0.5853333333333334
# Bayes第152轮，测试集上准确率： 0.536
# Bayes第152轮，验证集上准确率： 0.561
#
#
# Bayes第153轮，训练集上准确率： 0.5853333333333334
# Bayes第153轮，测试集上准确率： 0.536
# Bayes第153轮，验证集上准确率： 0.561
#
#
# Bayes第154轮，训练集上准确率： 0.5853333333333334
# Bayes第154轮，测试集上准确率： 0.536
# Bayes第154轮，验证集上准确率： 0.561
#
#
# Bayes第155轮，训练集上准确率： 0.5853333333333334
# Bayes第155轮，测试集上准确率： 0.536
# Bayes第155轮，验证集上准确率： 0.561
#
#
# Bayes第156轮，训练集上准确率： 0.5853333333333334
# Bayes第156轮，测试集上准确率： 0.536
# Bayes第156轮，验证集上准确率： 0.561
#
#
# Bayes第157轮，训练集上准确率： 0.5853333333333334
# Bayes第157轮，测试集上准确率： 0.536
# Bayes第157轮，验证集上准确率： 0.561
#
#
# Bayes第158轮，训练集上准确率： 0.5853333333333334
# Bayes第158轮，测试集上准确率： 0.536
# Bayes第158轮，验证集上准确率： 0.561
#
#
# Bayes第159轮，训练集上准确率： 0.5853333333333334
# Bayes第159轮，测试集上准确率： 0.536
# Bayes第159轮，验证集上准确率： 0.561
#
#
# Bayes第160轮，训练集上准确率： 0.5853333333333334
# Bayes第160轮，测试集上准确率： 0.536
# Bayes第160轮，验证集上准确率： 0.561
#
#
# Bayes第161轮，训练集上准确率： 0.5853333333333334
# Bayes第161轮，测试集上准确率： 0.536
# Bayes第161轮，验证集上准确率： 0.561
#
#
# Bayes第162轮，训练集上准确率： 0.5853333333333334
# Bayes第162轮，测试集上准确率： 0.536
# Bayes第162轮，验证集上准确率： 0.561
#
#
# Bayes第163轮，训练集上准确率： 0.5853333333333334
# Bayes第163轮，测试集上准确率： 0.536
# Bayes第163轮，验证集上准确率： 0.561
#
#
# Bayes第164轮，训练集上准确率： 0.5853333333333334
# Bayes第164轮，测试集上准确率： 0.536
# Bayes第164轮，验证集上准确率： 0.561
#
#
# Bayes第165轮，训练集上准确率： 0.5853333333333334
# Bayes第165轮，测试集上准确率： 0.536
# Bayes第165轮，验证集上准确率： 0.561
#
#
# Bayes第166轮，训练集上准确率： 0.5853333333333334
# Bayes第166轮，测试集上准确率： 0.536
# Bayes第166轮，验证集上准确率： 0.561
#
#
# Bayes第167轮，训练集上准确率： 0.5853333333333334
# Bayes第167轮，测试集上准确率： 0.536
# Bayes第167轮，验证集上准确率： 0.561
#
#
# Bayes第168轮，训练集上准确率： 0.5853333333333334
# Bayes第168轮，测试集上准确率： 0.536
# Bayes第168轮，验证集上准确率： 0.561
#
#
# Bayes第169轮，训练集上准确率： 0.5853333333333334
# Bayes第169轮，测试集上准确率： 0.536
# Bayes第169轮，验证集上准确率： 0.561
#
#
# Bayes第170轮，训练集上准确率： 0.5853333333333334
# Bayes第170轮，测试集上准确率： 0.536
# Bayes第170轮，验证集上准确率： 0.561
#
#
# Bayes第171轮，训练集上准确率： 0.5853333333333334
# Bayes第171轮，测试集上准确率： 0.536
# Bayes第171轮，验证集上准确率： 0.561
#
#
# Bayes第172轮，训练集上准确率： 0.5853333333333334
# Bayes第172轮，测试集上准确率： 0.536
# Bayes第172轮，验证集上准确率： 0.561
#
#
# Bayes第173轮，训练集上准确率： 0.5853333333333334
# Bayes第173轮，测试集上准确率： 0.536
# Bayes第173轮，验证集上准确率： 0.561
#
#
# Bayes第174轮，训练集上准确率： 0.5853333333333334
# Bayes第174轮，测试集上准确率： 0.536
# Bayes第174轮，验证集上准确率： 0.561
#
#
# Bayes第175轮，训练集上准确率： 0.5853333333333334
# Bayes第175轮，测试集上准确率： 0.536
# Bayes第175轮，验证集上准确率： 0.561
#
#
# Bayes第176轮，训练集上准确率： 0.5853333333333334
# Bayes第176轮，测试集上准确率： 0.536
# Bayes第176轮，验证集上准确率： 0.561
#
#
# Bayes第177轮，训练集上准确率： 0.5853333333333334
# Bayes第177轮，测试集上准确率： 0.536
# Bayes第177轮，验证集上准确率： 0.561
#
#
# Bayes第178轮，训练集上准确率： 0.5853333333333334
# Bayes第178轮，测试集上准确率： 0.536
# Bayes第178轮，验证集上准确率： 0.561
#
#
# Bayes第179轮，训练集上准确率： 0.5853333333333334
# Bayes第179轮，测试集上准确率： 0.536
# Bayes第179轮，验证集上准确率： 0.561
#
#
# Bayes第180轮，训练集上准确率： 0.5853333333333334
# Bayes第180轮，测试集上准确率： 0.536
# Bayes第180轮，验证集上准确率： 0.561
#
#
# Bayes第181轮，训练集上准确率： 0.5853333333333334
# Bayes第181轮，测试集上准确率： 0.536
# Bayes第181轮，验证集上准确率： 0.561
#
#
# Bayes第182轮，训练集上准确率： 0.5853333333333334
# Bayes第182轮，测试集上准确率： 0.536
# Bayes第182轮，验证集上准确率： 0.561
#
#
# Bayes第183轮，训练集上准确率： 0.5853333333333334
# Bayes第183轮，测试集上准确率： 0.536
# Bayes第183轮，验证集上准确率： 0.561
#
#
# Bayes第184轮，训练集上准确率： 0.5853333333333334
# Bayes第184轮，测试集上准确率： 0.536
# Bayes第184轮，验证集上准确率： 0.561
#
#
# Bayes第185轮，训练集上准确率： 0.5853333333333334
# Bayes第185轮，测试集上准确率： 0.536
# Bayes第185轮，验证集上准确率： 0.561
#
#
# Bayes第186轮，训练集上准确率： 0.5853333333333334
# Bayes第186轮，测试集上准确率： 0.536
# Bayes第186轮，验证集上准确率： 0.561
#
#
# Bayes第187轮，训练集上准确率： 0.5853333333333334
# Bayes第187轮，测试集上准确率： 0.536
# Bayes第187轮，验证集上准确率： 0.561
#
#
# Bayes第188轮，训练集上准确率： 0.5853333333333334
# Bayes第188轮，测试集上准确率： 0.536
# Bayes第188轮，验证集上准确率： 0.561
#
#
# Bayes第189轮，训练集上准确率： 0.5853333333333334
# Bayes第189轮，测试集上准确率： 0.536
# Bayes第189轮，验证集上准确率： 0.561
#
#
# Bayes第190轮，训练集上准确率： 0.5853333333333334
# Bayes第190轮，测试集上准确率： 0.536
# Bayes第190轮，验证集上准确率： 0.561
#
#
# Bayes第191轮，训练集上准确率： 0.5853333333333334
# Bayes第191轮，测试集上准确率： 0.536
# Bayes第191轮，验证集上准确率： 0.561
#
#
# Bayes第192轮，训练集上准确率： 0.5853333333333334
# Bayes第192轮，测试集上准确率： 0.536
# Bayes第192轮，验证集上准确率： 0.561
#
#
# Bayes第193轮，训练集上准确率： 0.5853333333333334
# Bayes第193轮，测试集上准确率： 0.536
# Bayes第193轮，验证集上准确率： 0.561
#
#
# Bayes第194轮，训练集上准确率： 0.5853333333333334
# Bayes第194轮，测试集上准确率： 0.536
# Bayes第194轮，验证集上准确率： 0.561
#
#
# Bayes第195轮，训练集上准确率： 0.5853333333333334
# Bayes第195轮，测试集上准确率： 0.536
# Bayes第195轮，验证集上准确率： 0.561
#
#
# Bayes第196轮，训练集上准确率： 0.5853333333333334
# Bayes第196轮，测试集上准确率： 0.536
# Bayes第196轮，验证集上准确率： 0.561
#
#
# Bayes第197轮，训练集上准确率： 0.5853333333333334
# Bayes第197轮，测试集上准确率： 0.536
# Bayes第197轮，验证集上准确率： 0.561
#
#
# Bayes第198轮，训练集上准确率： 0.5853333333333334
# Bayes第198轮，测试集上准确率： 0.536
# Bayes第198轮，验证集上准确率： 0.561
#
#
# Bayes第199轮，训练集上准确率： 0.5853333333333334
# Bayes第199轮，测试集上准确率： 0.536
# Bayes第199轮，验证集上准确率： 0.561
#
#
# Bayes第200轮，训练集上准确率： 0.5853333333333334
# Bayes第200轮，测试集上准确率： 0.536
# Bayes第200轮，验证集上准确率： 0.561
#
#
# Bayes第201轮，训练集上准确率： 0.5853333333333334
# Bayes第201轮，测试集上准确率： 0.536
# Bayes第201轮，验证集上准确率： 0.561
#
#
# Bayes第202轮，训练集上准确率： 0.5853333333333334
# Bayes第202轮，测试集上准确率： 0.536
# Bayes第202轮，验证集上准确率： 0.561
#
#
# Bayes第203轮，训练集上准确率： 0.5853333333333334
# Bayes第203轮，测试集上准确率： 0.536
# Bayes第203轮，验证集上准确率： 0.561
#
#
# Bayes第204轮，训练集上准确率： 0.5853333333333334
# Bayes第204轮，测试集上准确率： 0.536
# Bayes第204轮，验证集上准确率： 0.561
#
#
# Bayes第205轮，训练集上准确率： 0.5853333333333334
# Bayes第205轮，测试集上准确率： 0.536
# Bayes第205轮，验证集上准确率： 0.561
#
#
# Bayes第206轮，训练集上准确率： 0.5853333333333334
# Bayes第206轮，测试集上准确率： 0.536
# Bayes第206轮，验证集上准确率： 0.561
#
#
# Bayes第207轮，训练集上准确率： 0.5853333333333334
# Bayes第207轮，测试集上准确率： 0.536
# Bayes第207轮，验证集上准确率： 0.561
#
#
# Bayes第208轮，训练集上准确率： 0.5853333333333334
# Bayes第208轮，测试集上准确率： 0.536
# Bayes第208轮，验证集上准确率： 0.561
#
#
# Bayes第209轮，训练集上准确率： 0.5853333333333334
# Bayes第209轮，测试集上准确率： 0.536
# Bayes第209轮，验证集上准确率： 0.561
#
#
# Bayes第210轮，训练集上准确率： 0.5853333333333334
# Bayes第210轮，测试集上准确率： 0.536
# Bayes第210轮，验证集上准确率： 0.561
#
#
# Bayes第211轮，训练集上准确率： 0.5853333333333334
# Bayes第211轮，测试集上准确率： 0.536
# Bayes第211轮，验证集上准确率： 0.561
#
#
# Bayes第212轮，训练集上准确率： 0.5853333333333334
# Bayes第212轮，测试集上准确率： 0.536
# Bayes第212轮，验证集上准确率： 0.561
#
#
# Bayes第213轮，训练集上准确率： 0.5853333333333334
# Bayes第213轮，测试集上准确率： 0.536
# Bayes第213轮，验证集上准确率： 0.561
#
#
# Bayes第214轮，训练集上准确率： 0.5853333333333334
# Bayes第214轮，测试集上准确率： 0.536
# Bayes第214轮，验证集上准确率： 0.561
#
#
# Bayes第215轮，训练集上准确率： 0.5853333333333334
# Bayes第215轮，测试集上准确率： 0.536
# Bayes第215轮，验证集上准确率： 0.561
#
#
# Bayes第216轮，训练集上准确率： 0.5853333333333334
# Bayes第216轮，测试集上准确率： 0.536
# Bayes第216轮，验证集上准确率： 0.561
#
#
# Bayes第217轮，训练集上准确率： 0.5853333333333334
# Bayes第217轮，测试集上准确率： 0.536
# Bayes第217轮，验证集上准确率： 0.561
#
#
# Bayes第218轮，训练集上准确率： 0.5853333333333334
# Bayes第218轮，测试集上准确率： 0.536
# Bayes第218轮，验证集上准确率： 0.561
#
#
# Bayes第219轮，训练集上准确率： 0.5853333333333334
# Bayes第219轮，测试集上准确率： 0.536
# Bayes第219轮，验证集上准确率： 0.561
#
#
# Bayes第220轮，训练集上准确率： 0.5853333333333334
# Bayes第220轮，测试集上准确率： 0.536
# Bayes第220轮，验证集上准确率： 0.561
#
#
# Bayes第221轮，训练集上准确率： 0.5853333333333334
# Bayes第221轮，测试集上准确率： 0.536
# Bayes第221轮，验证集上准确率： 0.561
#
#
# Bayes第222轮，训练集上准确率： 0.5853333333333334
# Bayes第222轮，测试集上准确率： 0.536
# Bayes第222轮，验证集上准确率： 0.561
#
#
# Bayes第223轮，训练集上准确率： 0.5853333333333334
# Bayes第223轮，测试集上准确率： 0.536
# Bayes第223轮，验证集上准确率： 0.561
#
#
# Bayes第224轮，训练集上准确率： 0.5853333333333334
# Bayes第224轮，测试集上准确率： 0.536
# Bayes第224轮，验证集上准确率： 0.561
#
#
# Bayes第225轮，训练集上准确率： 0.5853333333333334
# Bayes第225轮，测试集上准确率： 0.536
# Bayes第225轮，验证集上准确率： 0.561
#
#
# Bayes第226轮，训练集上准确率： 0.5853333333333334
# Bayes第226轮，测试集上准确率： 0.536
# Bayes第226轮，验证集上准确率： 0.561
#
#
# Bayes第227轮，训练集上准确率： 0.5853333333333334
# Bayes第227轮，测试集上准确率： 0.536
# Bayes第227轮，验证集上准确率： 0.561
#
#
# Bayes第228轮，训练集上准确率： 0.5853333333333334
# Bayes第228轮，测试集上准确率： 0.536
# Bayes第228轮，验证集上准确率： 0.561
#
#
# Bayes第229轮，训练集上准确率： 0.5853333333333334
# Bayes第229轮，测试集上准确率： 0.536
# Bayes第229轮，验证集上准确率： 0.561
#
#
# Bayes第230轮，训练集上准确率： 0.5853333333333334
# Bayes第230轮，测试集上准确率： 0.536
# Bayes第230轮，验证集上准确率： 0.561
#
#
# Bayes第231轮，训练集上准确率： 0.5853333333333334
# Bayes第231轮，测试集上准确率： 0.536
# Bayes第231轮，验证集上准确率： 0.561
#
#
# Bayes第232轮，训练集上准确率： 0.5853333333333334
# Bayes第232轮，测试集上准确率： 0.536
# Bayes第232轮，验证集上准确率： 0.561
#
#
# Bayes第233轮，训练集上准确率： 0.5853333333333334
# Bayes第233轮，测试集上准确率： 0.536
# Bayes第233轮，验证集上准确率： 0.561
#
#
# Bayes第234轮，训练集上准确率： 0.5853333333333334
# Bayes第234轮，测试集上准确率： 0.536
# Bayes第234轮，验证集上准确率： 0.561
#
#
# Bayes第235轮，训练集上准确率： 0.5853333333333334
# Bayes第235轮，测试集上准确率： 0.536
# Bayes第235轮，验证集上准确率： 0.561
#
#
# Bayes第236轮，训练集上准确率： 0.5853333333333334
# Bayes第236轮，测试集上准确率： 0.536
# Bayes第236轮，验证集上准确率： 0.561
#
#
# Bayes第237轮，训练集上准确率： 0.5853333333333334
# Bayes第237轮，测试集上准确率： 0.536
# Bayes第237轮，验证集上准确率： 0.561
#
#
# Bayes第238轮，训练集上准确率： 0.5853333333333334
# Bayes第238轮，测试集上准确率： 0.536
# Bayes第238轮，验证集上准确率： 0.561
#
#
# Bayes第239轮，训练集上准确率： 0.5853333333333334
# Bayes第239轮，测试集上准确率： 0.536
# Bayes第239轮，验证集上准确率： 0.561
#
#
# Bayes第240轮，训练集上准确率： 0.5853333333333334
# Bayes第240轮，测试集上准确率： 0.536
# Bayes第240轮，验证集上准确率： 0.561
#
#
# Bayes第241轮，训练集上准确率： 0.5853333333333334
# Bayes第241轮，测试集上准确率： 0.536
# Bayes第241轮，验证集上准确率： 0.561
#
#
# Bayes第242轮，训练集上准确率： 0.5853333333333334
# Bayes第242轮，测试集上准确率： 0.536
# Bayes第242轮，验证集上准确率： 0.561
#
#
# Bayes第243轮，训练集上准确率： 0.5853333333333334
# Bayes第243轮，测试集上准确率： 0.536
# Bayes第243轮，验证集上准确率： 0.561
#
#
# Bayes第244轮，训练集上准确率： 0.5853333333333334
# Bayes第244轮，测试集上准确率： 0.536
# Bayes第244轮，验证集上准确率： 0.561
#
#
# Bayes第245轮，训练集上准确率： 0.5853333333333334
# Bayes第245轮，测试集上准确率： 0.536
# Bayes第245轮，验证集上准确率： 0.561
#
#
# Bayes第246轮，训练集上准确率： 0.5853333333333334
# Bayes第246轮，测试集上准确率： 0.536
# Bayes第246轮，验证集上准确率： 0.561
#
#
# Bayes第247轮，训练集上准确率： 0.5853333333333334
# Bayes第247轮，测试集上准确率： 0.536
# Bayes第247轮，验证集上准确率： 0.561
#
#
# Bayes第248轮，训练集上准确率： 0.5853333333333334
# Bayes第248轮，测试集上准确率： 0.536
# Bayes第248轮，验证集上准确率： 0.561
#
#
# Bayes第249轮，训练集上准确率： 0.5853333333333334
# Bayes第249轮，测试集上准确率： 0.536
# Bayes第249轮，验证集上准确率： 0.561
#
#
# Bayes第250轮，训练集上准确率： 0.5853333333333334
# Bayes第250轮，测试集上准确率： 0.536
# Bayes第250轮，验证集上准确率： 0.561
#
#
# Bayes第251轮，训练集上准确率： 0.5853333333333334
# Bayes第251轮，测试集上准确率： 0.536
# Bayes第251轮，验证集上准确率： 0.561
#
#
# Bayes第252轮，训练集上准确率： 0.5853333333333334
# Bayes第252轮，测试集上准确率： 0.536
# Bayes第252轮，验证集上准确率： 0.561
#
#
# Bayes第253轮，训练集上准确率： 0.5853333333333334
# Bayes第253轮，测试集上准确率： 0.536
# Bayes第253轮，验证集上准确率： 0.561
#
#
# Bayes第254轮，训练集上准确率： 0.5853333333333334
# Bayes第254轮，测试集上准确率： 0.536
# Bayes第254轮，验证集上准确率： 0.561
#
#
# Bayes第255轮，训练集上准确率： 0.5853333333333334
# Bayes第255轮，测试集上准确率： 0.536
# Bayes第255轮，验证集上准确率： 0.561
#
#
# Bayes第256轮，训练集上准确率： 0.5853333333333334
# Bayes第256轮，测试集上准确率： 0.536
# Bayes第256轮，验证集上准确率： 0.561
#
#
# Bayes第257轮，训练集上准确率： 0.5853333333333334
# Bayes第257轮，测试集上准确率： 0.536
# Bayes第257轮，验证集上准确率： 0.561
#
#
# Bayes第258轮，训练集上准确率： 0.5853333333333334
# Bayes第258轮，测试集上准确率： 0.536
# Bayes第258轮，验证集上准确率： 0.561
#
#
# Bayes第259轮，训练集上准确率： 0.5853333333333334
# Bayes第259轮，测试集上准确率： 0.536
# Bayes第259轮，验证集上准确率： 0.561
#
#
# Bayes第260轮，训练集上准确率： 0.5853333333333334
# Bayes第260轮，测试集上准确率： 0.536
# Bayes第260轮，验证集上准确率： 0.561
#
#
# Bayes第261轮，训练集上准确率： 0.5853333333333334
# Bayes第261轮，测试集上准确率： 0.536
# Bayes第261轮，验证集上准确率： 0.561
#
#
# Bayes第262轮，训练集上准确率： 0.5853333333333334
# Bayes第262轮，测试集上准确率： 0.536
# Bayes第262轮，验证集上准确率： 0.561
#
#
# Bayes第263轮，训练集上准确率： 0.5853333333333334
# Bayes第263轮，测试集上准确率： 0.536
# Bayes第263轮，验证集上准确率： 0.561
#
#
# Bayes第264轮，训练集上准确率： 0.5853333333333334
# Bayes第264轮，测试集上准确率： 0.536
# Bayes第264轮，验证集上准确率： 0.561
#
#
# Bayes第265轮，训练集上准确率： 0.5853333333333334
# Bayes第265轮，测试集上准确率： 0.536
# Bayes第265轮，验证集上准确率： 0.561
#
#
# Bayes第266轮，训练集上准确率： 0.5853333333333334
# Bayes第266轮，测试集上准确率： 0.536
# Bayes第266轮，验证集上准确率： 0.561
#
#
# Bayes第267轮，训练集上准确率： 0.5853333333333334
# Bayes第267轮，测试集上准确率： 0.536
# Bayes第267轮，验证集上准确率： 0.561
#
#
# Bayes第268轮，训练集上准确率： 0.5853333333333334
# Bayes第268轮，测试集上准确率： 0.536
# Bayes第268轮，验证集上准确率： 0.561
#
#
# Bayes第269轮，训练集上准确率： 0.5853333333333334
# Bayes第269轮，测试集上准确率： 0.536
# Bayes第269轮，验证集上准确率： 0.561
#
#
# Bayes第270轮，训练集上准确率： 0.5853333333333334
# Bayes第270轮，测试集上准确率： 0.536
# Bayes第270轮，验证集上准确率： 0.561
#
#
# Bayes第271轮，训练集上准确率： 0.5853333333333334
# Bayes第271轮，测试集上准确率： 0.536
# Bayes第271轮，验证集上准确率： 0.561
#
#
# Bayes第272轮，训练集上准确率： 0.5853333333333334
# Bayes第272轮，测试集上准确率： 0.536
# Bayes第272轮，验证集上准确率： 0.561
#
#
# Bayes第273轮，训练集上准确率： 0.5853333333333334
# Bayes第273轮，测试集上准确率： 0.536
# Bayes第273轮，验证集上准确率： 0.561
#
#
# Bayes第274轮，训练集上准确率： 0.5853333333333334
# Bayes第274轮，测试集上准确率： 0.536
# Bayes第274轮，验证集上准确率： 0.561
#
#
# Bayes第275轮，训练集上准确率： 0.5853333333333334
# Bayes第275轮，测试集上准确率： 0.536
# Bayes第275轮，验证集上准确率： 0.561
#
#
# Bayes第276轮，训练集上准确率： 0.5853333333333334
# Bayes第276轮，测试集上准确率： 0.536
# Bayes第276轮，验证集上准确率： 0.561
#
#
# Bayes第277轮，训练集上准确率： 0.5853333333333334
# Bayes第277轮，测试集上准确率： 0.536
# Bayes第277轮，验证集上准确率： 0.561
#
#
# Bayes第278轮，训练集上准确率： 0.5853333333333334
# Bayes第278轮，测试集上准确率： 0.536
# Bayes第278轮，验证集上准确率： 0.561
#
#
# Bayes第279轮，训练集上准确率： 0.5853333333333334
# Bayes第279轮，测试集上准确率： 0.536
# Bayes第279轮，验证集上准确率： 0.561
#
#
# Bayes第280轮，训练集上准确率： 0.5853333333333334
# Bayes第280轮，测试集上准确率： 0.536
# Bayes第280轮，验证集上准确率： 0.561
#
#
# Bayes第281轮，训练集上准确率： 0.5853333333333334
# Bayes第281轮，测试集上准确率： 0.536
# Bayes第281轮，验证集上准确率： 0.561
#
#
# Bayes第282轮，训练集上准确率： 0.5853333333333334
# Bayes第282轮，测试集上准确率： 0.536
# Bayes第282轮，验证集上准确率： 0.561
#
#
# Bayes第283轮，训练集上准确率： 0.5853333333333334
# Bayes第283轮，测试集上准确率： 0.536
# Bayes第283轮，验证集上准确率： 0.561
#
#
# Bayes第284轮，训练集上准确率： 0.5853333333333334
# Bayes第284轮，测试集上准确率： 0.536
# Bayes第284轮，验证集上准确率： 0.561
#
#
# Bayes第285轮，训练集上准确率： 0.5853333333333334
# Bayes第285轮，测试集上准确率： 0.536
# Bayes第285轮，验证集上准确率： 0.561
#
#
# Bayes第286轮，训练集上准确率： 0.5853333333333334
# Bayes第286轮，测试集上准确率： 0.536
# Bayes第286轮，验证集上准确率： 0.561
#
#
# Bayes第287轮，训练集上准确率： 0.5853333333333334
# Bayes第287轮，测试集上准确率： 0.536
# Bayes第287轮，验证集上准确率： 0.561
#
#
# Bayes第288轮，训练集上准确率： 0.5853333333333334
# Bayes第288轮，测试集上准确率： 0.536
# Bayes第288轮，验证集上准确率： 0.561
#
#
# Bayes第289轮，训练集上准确率： 0.5853333333333334
# Bayes第289轮，测试集上准确率： 0.536
# Bayes第289轮，验证集上准确率： 0.561
#
#
# Bayes第290轮，训练集上准确率： 0.5853333333333334
# Bayes第290轮，测试集上准确率： 0.536
# Bayes第290轮，验证集上准确率： 0.561
#
#
# Bayes第291轮，训练集上准确率： 0.5853333333333334
# Bayes第291轮，测试集上准确率： 0.536
# Bayes第291轮，验证集上准确率： 0.561
#
#
# Bayes第292轮，训练集上准确率： 0.5853333333333334
# Bayes第292轮，测试集上准确率： 0.536
# Bayes第292轮，验证集上准确率： 0.561
#
#
# Bayes第293轮，训练集上准确率： 0.5853333333333334
# Bayes第293轮，测试集上准确率： 0.536
# Bayes第293轮，验证集上准确率： 0.561
#
#
# Bayes第294轮，训练集上准确率： 0.5853333333333334
# Bayes第294轮，测试集上准确率： 0.536
# Bayes第294轮，验证集上准确率： 0.561
#
#
# Bayes第295轮，训练集上准确率： 0.5853333333333334
# Bayes第295轮，测试集上准确率： 0.536
# Bayes第295轮，验证集上准确率： 0.561
#
#
# Bayes第296轮，训练集上准确率： 0.5853333333333334
# Bayes第296轮，测试集上准确率： 0.536
# Bayes第296轮，验证集上准确率： 0.561
#
#
# Bayes第297轮，训练集上准确率： 0.5853333333333334
# Bayes第297轮，测试集上准确率： 0.536
# Bayes第297轮，验证集上准确率： 0.561
#
#
# Bayes第298轮，训练集上准确率： 0.5853333333333334
# Bayes第298轮，测试集上准确率： 0.536
# Bayes第298轮，验证集上准确率： 0.561
#
#
# Bayes第299轮，训练集上准确率： 0.5853333333333334
# Bayes第299轮，测试集上准确率： 0.536
# Bayes第299轮，验证集上准确率： 0.561
#
#
# Bayes第300轮，训练集上准确率： 0.5853333333333334
# Bayes第300轮，测试集上准确率： 0.536
# Bayes第300轮，验证集上准确率： 0.561
#
#
# Bayes第301轮，训练集上准确率： 0.5853333333333334
# Bayes第301轮，测试集上准确率： 0.536
# Bayes第301轮，验证集上准确率： 0.561
#
#
# Bayes第302轮，训练集上准确率： 0.5853333333333334
# Bayes第302轮，测试集上准确率： 0.536
# Bayes第302轮，验证集上准确率： 0.561
#
#
# Bayes第303轮，训练集上准确率： 0.5853333333333334
# Bayes第303轮，测试集上准确率： 0.536
# Bayes第303轮，验证集上准确率： 0.561
#
#
# Bayes第304轮，训练集上准确率： 0.5853333333333334
# Bayes第304轮，测试集上准确率： 0.536
# Bayes第304轮，验证集上准确率： 0.561
#
#
# Bayes第305轮，训练集上准确率： 0.5853333333333334
# Bayes第305轮，测试集上准确率： 0.536
# Bayes第305轮，验证集上准确率： 0.561
#
#
# Bayes第306轮，训练集上准确率： 0.5853333333333334
# Bayes第306轮，测试集上准确率： 0.536
# Bayes第306轮，验证集上准确率： 0.561
#
#
# Bayes第307轮，训练集上准确率： 0.5853333333333334
# Bayes第307轮，测试集上准确率： 0.536
# Bayes第307轮，验证集上准确率： 0.561
#
#
# Bayes第308轮，训练集上准确率： 0.5853333333333334
# Bayes第308轮，测试集上准确率： 0.536
# Bayes第308轮，验证集上准确率： 0.561
#
#
# Bayes第309轮，训练集上准确率： 0.5853333333333334
# Bayes第309轮，测试集上准确率： 0.536
# Bayes第309轮，验证集上准确率： 0.561
#
#
# Bayes第310轮，训练集上准确率： 0.5853333333333334
# Bayes第310轮，测试集上准确率： 0.536
# Bayes第310轮，验证集上准确率： 0.561
#
#
# Bayes第311轮，训练集上准确率： 0.5853333333333334
# Bayes第311轮，测试集上准确率： 0.536
# Bayes第311轮，验证集上准确率： 0.561
#
#
# Bayes第312轮，训练集上准确率： 0.5853333333333334
# Bayes第312轮，测试集上准确率： 0.536
# Bayes第312轮，验证集上准确率： 0.561
#
#
# Bayes第313轮，训练集上准确率： 0.5853333333333334
# Bayes第313轮，测试集上准确率： 0.536
# Bayes第313轮，验证集上准确率： 0.561
#
#
# Bayes第314轮，训练集上准确率： 0.5853333333333334
# Bayes第314轮，测试集上准确率： 0.536
# Bayes第314轮，验证集上准确率： 0.561
#
#
# Bayes第315轮，训练集上准确率： 0.5853333333333334
# Bayes第315轮，测试集上准确率： 0.536
# Bayes第315轮，验证集上准确率： 0.561
#
#
# Bayes第316轮，训练集上准确率： 0.5853333333333334
# Bayes第316轮，测试集上准确率： 0.536
# Bayes第316轮，验证集上准确率： 0.561
#
#
# Bayes第317轮，训练集上准确率： 0.5853333333333334
# Bayes第317轮，测试集上准确率： 0.536
# Bayes第317轮，验证集上准确率： 0.561
#
#
# Bayes第318轮，训练集上准确率： 0.5853333333333334
# Bayes第318轮，测试集上准确率： 0.536
# Bayes第318轮，验证集上准确率： 0.561
#
#
# Bayes第319轮，训练集上准确率： 0.5853333333333334
# Bayes第319轮，测试集上准确率： 0.536
# Bayes第319轮，验证集上准确率： 0.561
#
#
# Bayes第320轮，训练集上准确率： 0.5853333333333334
# Bayes第320轮，测试集上准确率： 0.536
# Bayes第320轮，验证集上准确率： 0.561
#
#
# Bayes第321轮，训练集上准确率： 0.5853333333333334
# Bayes第321轮，测试集上准确率： 0.536
# Bayes第321轮，验证集上准确率： 0.561
#
#
# Bayes第322轮，训练集上准确率： 0.5853333333333334
# Bayes第322轮，测试集上准确率： 0.536
# Bayes第322轮，验证集上准确率： 0.561
#
#
# Bayes第323轮，训练集上准确率： 0.5853333333333334
# Bayes第323轮，测试集上准确率： 0.536
# Bayes第323轮，验证集上准确率： 0.561
#
#
# Bayes第324轮，训练集上准确率： 0.5853333333333334
# Bayes第324轮，测试集上准确率： 0.536
# Bayes第324轮，验证集上准确率： 0.561
#
#
# Bayes第325轮，训练集上准确率： 0.5853333333333334
# Bayes第325轮，测试集上准确率： 0.536
# Bayes第325轮，验证集上准确率： 0.561
#
#
# Bayes第326轮，训练集上准确率： 0.5853333333333334
# Bayes第326轮，测试集上准确率： 0.536
# Bayes第326轮，验证集上准确率： 0.561
#
#
# Bayes第327轮，训练集上准确率： 0.5853333333333334
# Bayes第327轮，测试集上准确率： 0.536
# Bayes第327轮，验证集上准确率： 0.561
#
#
# Bayes第328轮，训练集上准确率： 0.5853333333333334
# Bayes第328轮，测试集上准确率： 0.536
# Bayes第328轮，验证集上准确率： 0.561
#
#
# Bayes第329轮，训练集上准确率： 0.5853333333333334
# Bayes第329轮，测试集上准确率： 0.536
# Bayes第329轮，验证集上准确率： 0.561
#
#
# Bayes第330轮，训练集上准确率： 0.5853333333333334
# Bayes第330轮，测试集上准确率： 0.536
# Bayes第330轮，验证集上准确率： 0.561
#
#
# Bayes第331轮，训练集上准确率： 0.5853333333333334
# Bayes第331轮，测试集上准确率： 0.536
# Bayes第331轮，验证集上准确率： 0.561
#
#
# Bayes第332轮，训练集上准确率： 0.5853333333333334
# Bayes第332轮，测试集上准确率： 0.536
# Bayes第332轮，验证集上准确率： 0.561
#
#
# Bayes第333轮，训练集上准确率： 0.5853333333333334
# Bayes第333轮，测试集上准确率： 0.536
# Bayes第333轮，验证集上准确率： 0.561
#
#
# Bayes第334轮，训练集上准确率： 0.5853333333333334
# Bayes第334轮，测试集上准确率： 0.536
# Bayes第334轮，验证集上准确率： 0.561
#
#
# Bayes第335轮，训练集上准确率： 0.5853333333333334
# Bayes第335轮，测试集上准确率： 0.536
# Bayes第335轮，验证集上准确率： 0.561
#
#
# Bayes第336轮，训练集上准确率： 0.5853333333333334
# Bayes第336轮，测试集上准确率： 0.536
# Bayes第336轮，验证集上准确率： 0.561
#
#
# Bayes第337轮，训练集上准确率： 0.5853333333333334
# Bayes第337轮，测试集上准确率： 0.536
# Bayes第337轮，验证集上准确率： 0.561
#
#
# Bayes第338轮，训练集上准确率： 0.5853333333333334
# Bayes第338轮，测试集上准确率： 0.536
# Bayes第338轮，验证集上准确率： 0.561
#
#
# Bayes第339轮，训练集上准确率： 0.5853333333333334
# Bayes第339轮，测试集上准确率： 0.536
# Bayes第339轮，验证集上准确率： 0.561
#
#
# Bayes第340轮，训练集上准确率： 0.5853333333333334
# Bayes第340轮，测试集上准确率： 0.536
# Bayes第340轮，验证集上准确率： 0.561
#
#
# Bayes第341轮，训练集上准确率： 0.5853333333333334
# Bayes第341轮，测试集上准确率： 0.536
# Bayes第341轮，验证集上准确率： 0.561
#
#
# Bayes第342轮，训练集上准确率： 0.5853333333333334
# Bayes第342轮，测试集上准确率： 0.536
# Bayes第342轮，验证集上准确率： 0.561
#
#
# Bayes第343轮，训练集上准确率： 0.5853333333333334
# Bayes第343轮，测试集上准确率： 0.536
# Bayes第343轮，验证集上准确率： 0.561
#
#
# Bayes第344轮，训练集上准确率： 0.5853333333333334
# Bayes第344轮，测试集上准确率： 0.536
# Bayes第344轮，验证集上准确率： 0.561
#
#
# Bayes第345轮，训练集上准确率： 0.5853333333333334
# Bayes第345轮，测试集上准确率： 0.536
# Bayes第345轮，验证集上准确率： 0.561
#
#
# Bayes第346轮，训练集上准确率： 0.5853333333333334
# Bayes第346轮，测试集上准确率： 0.536
# Bayes第346轮，验证集上准确率： 0.561
#
#
# Bayes第347轮，训练集上准确率： 0.5853333333333334
# Bayes第347轮，测试集上准确率： 0.536
# Bayes第347轮，验证集上准确率： 0.561
#
#
# Bayes第348轮，训练集上准确率： 0.5853333333333334
# Bayes第348轮，测试集上准确率： 0.536
# Bayes第348轮，验证集上准确率： 0.561
#
#
# Bayes第349轮，训练集上准确率： 0.5853333333333334
# Bayes第349轮，测试集上准确率： 0.536
# Bayes第349轮，验证集上准确率： 0.561
#
#
# Bayes第350轮，训练集上准确率： 0.5853333333333334
# Bayes第350轮，测试集上准确率： 0.536
# Bayes第350轮，验证集上准确率： 0.561
#
#
# Bayes第351轮，训练集上准确率： 0.5853333333333334
# Bayes第351轮，测试集上准确率： 0.536
# Bayes第351轮，验证集上准确率： 0.561
#
#
# Bayes第352轮，训练集上准确率： 0.5853333333333334
# Bayes第352轮，测试集上准确率： 0.536
# Bayes第352轮，验证集上准确率： 0.561
#
#
# Bayes第353轮，训练集上准确率： 0.5853333333333334
# Bayes第353轮，测试集上准确率： 0.536
# Bayes第353轮，验证集上准确率： 0.561
#
#
# Bayes第354轮，训练集上准确率： 0.5853333333333334
# Bayes第354轮，测试集上准确率： 0.536
# Bayes第354轮，验证集上准确率： 0.561
#
#
# Bayes第355轮，训练集上准确率： 0.5853333333333334
# Bayes第355轮，测试集上准确率： 0.536
# Bayes第355轮，验证集上准确率： 0.561
#
#
# Bayes第356轮，训练集上准确率： 0.5853333333333334
# Bayes第356轮，测试集上准确率： 0.536
# Bayes第356轮，验证集上准确率： 0.561
#
#
# Bayes第357轮，训练集上准确率： 0.5853333333333334
# Bayes第357轮，测试集上准确率： 0.536
# Bayes第357轮，验证集上准确率： 0.561
#
#
# Bayes第358轮，训练集上准确率： 0.5853333333333334
# Bayes第358轮，测试集上准确率： 0.536
# Bayes第358轮，验证集上准确率： 0.561
#
#
# Bayes第359轮，训练集上准确率： 0.5853333333333334
# Bayes第359轮，测试集上准确率： 0.536
# Bayes第359轮，验证集上准确率： 0.561
#
#
# Bayes第360轮，训练集上准确率： 0.5853333333333334
# Bayes第360轮，测试集上准确率： 0.536
# Bayes第360轮，验证集上准确率： 0.561
#
#
# Bayes第361轮，训练集上准确率： 0.5853333333333334
# Bayes第361轮，测试集上准确率： 0.536
# Bayes第361轮，验证集上准确率： 0.561
#
#
# Bayes第362轮，训练集上准确率： 0.5853333333333334
# Bayes第362轮，测试集上准确率： 0.536
# Bayes第362轮，验证集上准确率： 0.561
#
#
# Bayes第363轮，训练集上准确率： 0.5853333333333334
# Bayes第363轮，测试集上准确率： 0.536
# Bayes第363轮，验证集上准确率： 0.561
#
#
# Bayes第364轮，训练集上准确率： 0.5853333333333334
# Bayes第364轮，测试集上准确率： 0.536
# Bayes第364轮，验证集上准确率： 0.561
#
#
# Bayes第365轮，训练集上准确率： 0.5853333333333334
# Bayes第365轮，测试集上准确率： 0.536
# Bayes第365轮，验证集上准确率： 0.561
#
#
# Bayes第366轮，训练集上准确率： 0.5853333333333334
# Bayes第366轮，测试集上准确率： 0.536
# Bayes第366轮，验证集上准确率： 0.561
#
#
# Bayes第367轮，训练集上准确率： 0.5853333333333334
# Bayes第367轮，测试集上准确率： 0.536
# Bayes第367轮，验证集上准确率： 0.561
#
#
# Bayes第368轮，训练集上准确率： 0.5853333333333334
# Bayes第368轮，测试集上准确率： 0.536
# Bayes第368轮，验证集上准确率： 0.561
#
#
# Bayes第369轮，训练集上准确率： 0.5853333333333334
# Bayes第369轮，测试集上准确率： 0.536
# Bayes第369轮，验证集上准确率： 0.561
#
#
# Bayes第370轮，训练集上准确率： 0.5853333333333334
# Bayes第370轮，测试集上准确率： 0.536
# Bayes第370轮，验证集上准确率： 0.561
#
#
# Bayes第371轮，训练集上准确率： 0.5853333333333334
# Bayes第371轮，测试集上准确率： 0.536
# Bayes第371轮，验证集上准确率： 0.561
#
#
# Bayes第372轮，训练集上准确率： 0.5853333333333334
# Bayes第372轮，测试集上准确率： 0.536
# Bayes第372轮，验证集上准确率： 0.561
#
#
# Bayes第373轮，训练集上准确率： 0.5853333333333334
# Bayes第373轮，测试集上准确率： 0.536
# Bayes第373轮，验证集上准确率： 0.561
#
#
# Bayes第374轮，训练集上准确率： 0.5853333333333334
# Bayes第374轮，测试集上准确率： 0.536
# Bayes第374轮，验证集上准确率： 0.561
#
#
# Bayes第375轮，训练集上准确率： 0.5853333333333334
# Bayes第375轮，测试集上准确率： 0.536
# Bayes第375轮，验证集上准确率： 0.561
#
#
# Bayes第376轮，训练集上准确率： 0.5853333333333334
# Bayes第376轮，测试集上准确率： 0.536
# Bayes第376轮，验证集上准确率： 0.561
#
#
# Bayes第377轮，训练集上准确率： 0.5853333333333334
# Bayes第377轮，测试集上准确率： 0.536
# Bayes第377轮，验证集上准确率： 0.561
#
#
# Bayes第378轮，训练集上准确率： 0.5853333333333334
# Bayes第378轮，测试集上准确率： 0.536
# Bayes第378轮，验证集上准确率： 0.561
#
#
# Bayes第379轮，训练集上准确率： 0.5853333333333334
# Bayes第379轮，测试集上准确率： 0.536
# Bayes第379轮，验证集上准确率： 0.561
#
#
# Bayes第380轮，训练集上准确率： 0.5853333333333334
# Bayes第380轮，测试集上准确率： 0.536
# Bayes第380轮，验证集上准确率： 0.561
#
#
# Bayes第381轮，训练集上准确率： 0.5853333333333334
# Bayes第381轮，测试集上准确率： 0.536
# Bayes第381轮，验证集上准确率： 0.561
#
#
# Bayes第382轮，训练集上准确率： 0.5853333333333334
# Bayes第382轮，测试集上准确率： 0.536
# Bayes第382轮，验证集上准确率： 0.561
#
#
# Bayes第383轮，训练集上准确率： 0.5853333333333334
# Bayes第383轮，测试集上准确率： 0.536
# Bayes第383轮，验证集上准确率： 0.561
#
#
# Bayes第384轮，训练集上准确率： 0.5853333333333334
# Bayes第384轮，测试集上准确率： 0.536
# Bayes第384轮，验证集上准确率： 0.561
#
#
# Bayes第385轮，训练集上准确率： 0.5853333333333334
# Bayes第385轮，测试集上准确率： 0.536
# Bayes第385轮，验证集上准确率： 0.561
#
#
# Bayes第386轮，训练集上准确率： 0.5853333333333334
# Bayes第386轮，测试集上准确率： 0.536
# Bayes第386轮，验证集上准确率： 0.561
#
#
# Bayes第387轮，训练集上准确率： 0.5853333333333334
# Bayes第387轮，测试集上准确率： 0.536
# Bayes第387轮，验证集上准确率： 0.561
#
#
# Bayes第388轮，训练集上准确率： 0.5853333333333334
# Bayes第388轮，测试集上准确率： 0.536
# Bayes第388轮，验证集上准确率： 0.561
#
#
# Bayes第389轮，训练集上准确率： 0.5853333333333334
# Bayes第389轮，测试集上准确率： 0.536
# Bayes第389轮，验证集上准确率： 0.561
#
#
# Bayes第390轮，训练集上准确率： 0.5853333333333334
# Bayes第390轮，测试集上准确率： 0.536
# Bayes第390轮，验证集上准确率： 0.561
#
#
# Bayes第391轮，训练集上准确率： 0.5853333333333334
# Bayes第391轮，测试集上准确率： 0.536
# Bayes第391轮，验证集上准确率： 0.561
#
#
# Bayes第392轮，训练集上准确率： 0.5853333333333334
# Bayes第392轮，测试集上准确率： 0.536
# Bayes第392轮，验证集上准确率： 0.561
#
#
# Bayes第393轮，训练集上准确率： 0.5853333333333334
# Bayes第393轮，测试集上准确率： 0.536
# Bayes第393轮，验证集上准确率： 0.561
#
#
# Bayes第394轮，训练集上准确率： 0.5853333333333334
# Bayes第394轮，测试集上准确率： 0.536
# Bayes第394轮，验证集上准确率： 0.561
#
#
# Bayes第395轮，训练集上准确率： 0.5853333333333334
# Bayes第395轮，测试集上准确率： 0.536
# Bayes第395轮，验证集上准确率： 0.561
#
#
# Bayes第396轮，训练集上准确率： 0.5853333333333334
# Bayes第396轮，测试集上准确率： 0.536
# Bayes第396轮，验证集上准确率： 0.561
#
#
# Bayes第397轮，训练集上准确率： 0.5853333333333334
# Bayes第397轮，测试集上准确率： 0.536
# Bayes第397轮，验证集上准确率： 0.561
#
#
# Bayes第398轮，训练集上准确率： 0.5853333333333334
# Bayes第398轮，测试集上准确率： 0.536
# Bayes第398轮，验证集上准确率： 0.561
#
#
# Bayes第399轮，训练集上准确率： 0.5853333333333334
# Bayes第399轮，测试集上准确率： 0.536
# Bayes第399轮，验证集上准确率： 0.561
#
#
# Bayes第400轮，训练集上准确率： 0.5853333333333334
# Bayes第400轮，测试集上准确率： 0.536
# Bayes第400轮，验证集上准确率： 0.561
#
#
# Bayes第401轮，训练集上准确率： 0.5853333333333334
# Bayes第401轮，测试集上准确率： 0.536
# Bayes第401轮，验证集上准确率： 0.561
#
#
# Bayes第402轮，训练集上准确率： 0.5853333333333334
# Bayes第402轮，测试集上准确率： 0.536
# Bayes第402轮，验证集上准确率： 0.561
#
#
# Bayes第403轮，训练集上准确率： 0.5853333333333334
# Bayes第403轮，测试集上准确率： 0.536
# Bayes第403轮，验证集上准确率： 0.561
#
#
# Bayes第404轮，训练集上准确率： 0.5853333333333334
# Bayes第404轮，测试集上准确率： 0.536
# Bayes第404轮，验证集上准确率： 0.561
#
#
# Bayes第405轮，训练集上准确率： 0.5853333333333334
# Bayes第405轮，测试集上准确率： 0.536
# Bayes第405轮，验证集上准确率： 0.561
#
#
# Bayes第406轮，训练集上准确率： 0.5853333333333334
# Bayes第406轮，测试集上准确率： 0.536
# Bayes第406轮，验证集上准确率： 0.561
#
#
# Bayes第407轮，训练集上准确率： 0.5853333333333334
# Bayes第407轮，测试集上准确率： 0.536
# Bayes第407轮，验证集上准确率： 0.561
#
#
# Bayes第408轮，训练集上准确率： 0.5853333333333334
# Bayes第408轮，测试集上准确率： 0.536
# Bayes第408轮，验证集上准确率： 0.561
#
#
# Bayes第409轮，训练集上准确率： 0.5853333333333334
# Bayes第409轮，测试集上准确率： 0.536
# Bayes第409轮，验证集上准确率： 0.561
#
#
# Bayes第410轮，训练集上准确率： 0.5853333333333334
# Bayes第410轮，测试集上准确率： 0.536
# Bayes第410轮，验证集上准确率： 0.561
#
#
# Bayes第411轮，训练集上准确率： 0.5853333333333334
# Bayes第411轮，测试集上准确率： 0.536
# Bayes第411轮，验证集上准确率： 0.561
#
#
# Bayes第412轮，训练集上准确率： 0.5853333333333334
# Bayes第412轮，测试集上准确率： 0.536
# Bayes第412轮，验证集上准确率： 0.561
#
#
# Bayes第413轮，训练集上准确率： 0.5853333333333334
# Bayes第413轮，测试集上准确率： 0.536
# Bayes第413轮，验证集上准确率： 0.561
#
#
# Bayes第414轮，训练集上准确率： 0.5853333333333334
# Bayes第414轮，测试集上准确率： 0.536
# Bayes第414轮，验证集上准确率： 0.561
#
#
# Bayes第415轮，训练集上准确率： 0.5853333333333334
# Bayes第415轮，测试集上准确率： 0.536
# Bayes第415轮，验证集上准确率： 0.561
#
#
# Bayes第416轮，训练集上准确率： 0.5853333333333334
# Bayes第416轮，测试集上准确率： 0.536
# Bayes第416轮，验证集上准确率： 0.561
#
#
# Bayes第417轮，训练集上准确率： 0.5853333333333334
# Bayes第417轮，测试集上准确率： 0.536
# Bayes第417轮，验证集上准确率： 0.561
#
#
# Bayes第418轮，训练集上准确率： 0.5853333333333334
# Bayes第418轮，测试集上准确率： 0.536
# Bayes第418轮，验证集上准确率： 0.561
#
#
# Bayes第419轮，训练集上准确率： 0.5853333333333334
# Bayes第419轮，测试集上准确率： 0.536
# Bayes第419轮，验证集上准确率： 0.561
#
#
# Bayes第420轮，训练集上准确率： 0.5853333333333334
# Bayes第420轮，测试集上准确率： 0.536
# Bayes第420轮，验证集上准确率： 0.561
#
#
# Bayes第421轮，训练集上准确率： 0.5853333333333334
# Bayes第421轮，测试集上准确率： 0.536
# Bayes第421轮，验证集上准确率： 0.561
#
#
# Bayes第422轮，训练集上准确率： 0.5853333333333334
# Bayes第422轮，测试集上准确率： 0.536
# Bayes第422轮，验证集上准确率： 0.561
#
#
# Bayes第423轮，训练集上准确率： 0.5853333333333334
# Bayes第423轮，测试集上准确率： 0.536
# Bayes第423轮，验证集上准确率： 0.561
#
#
# Bayes第424轮，训练集上准确率： 0.5853333333333334
# Bayes第424轮，测试集上准确率： 0.536
# Bayes第424轮，验证集上准确率： 0.561
#
#
# Bayes第425轮，训练集上准确率： 0.5853333333333334
# Bayes第425轮，测试集上准确率： 0.536
# Bayes第425轮，验证集上准确率： 0.561
#
#
# Bayes第426轮，训练集上准确率： 0.5853333333333334
# Bayes第426轮，测试集上准确率： 0.536
# Bayes第426轮，验证集上准确率： 0.561
#
#
# Bayes第427轮，训练集上准确率： 0.5853333333333334
# Bayes第427轮，测试集上准确率： 0.536
# Bayes第427轮，验证集上准确率： 0.561
#
#
# Bayes第428轮，训练集上准确率： 0.5853333333333334
# Bayes第428轮，测试集上准确率： 0.536
# Bayes第428轮，验证集上准确率： 0.561
#
#
# Bayes第429轮，训练集上准确率： 0.5853333333333334
# Bayes第429轮，测试集上准确率： 0.536
# Bayes第429轮，验证集上准确率： 0.561
#
#
# Bayes第430轮，训练集上准确率： 0.5853333333333334
# Bayes第430轮，测试集上准确率： 0.536
# Bayes第430轮，验证集上准确率： 0.561
#
#
# Bayes第431轮，训练集上准确率： 0.5853333333333334
# Bayes第431轮，测试集上准确率： 0.536
# Bayes第431轮，验证集上准确率： 0.561
#
#
# Bayes第432轮，训练集上准确率： 0.5853333333333334
# Bayes第432轮，测试集上准确率： 0.536
# Bayes第432轮，验证集上准确率： 0.561
#
#
# Bayes第433轮，训练集上准确率： 0.5853333333333334
# Bayes第433轮，测试集上准确率： 0.536
# Bayes第433轮，验证集上准确率： 0.561
#
#
# Bayes第434轮，训练集上准确率： 0.5853333333333334
# Bayes第434轮，测试集上准确率： 0.536
# Bayes第434轮，验证集上准确率： 0.561
#
#
# Bayes第435轮，训练集上准确率： 0.5853333333333334
# Bayes第435轮，测试集上准确率： 0.536
# Bayes第435轮，验证集上准确率： 0.561
#
#
# Bayes第436轮，训练集上准确率： 0.5853333333333334
# Bayes第436轮，测试集上准确率： 0.536
# Bayes第436轮，验证集上准确率： 0.561
#
#
# Bayes第437轮，训练集上准确率： 0.5853333333333334
# Bayes第437轮，测试集上准确率： 0.536
# Bayes第437轮，验证集上准确率： 0.561
#
#
# Bayes第438轮，训练集上准确率： 0.5853333333333334
# Bayes第438轮，测试集上准确率： 0.536
# Bayes第438轮，验证集上准确率： 0.561
#
#
# Bayes第439轮，训练集上准确率： 0.5853333333333334
# Bayes第439轮，测试集上准确率： 0.536
# Bayes第439轮，验证集上准确率： 0.561
#
#
# Bayes第440轮，训练集上准确率： 0.5853333333333334
# Bayes第440轮，测试集上准确率： 0.536
# Bayes第440轮，验证集上准确率： 0.561
#
#
# Bayes第441轮，训练集上准确率： 0.5853333333333334
# Bayes第441轮，测试集上准确率： 0.536
# Bayes第441轮，验证集上准确率： 0.561
#
#
# Bayes第442轮，训练集上准确率： 0.5853333333333334
# Bayes第442轮，测试集上准确率： 0.536
# Bayes第442轮，验证集上准确率： 0.561
#
#
# Bayes第443轮，训练集上准确率： 0.5853333333333334
# Bayes第443轮，测试集上准确率： 0.536
# Bayes第443轮，验证集上准确率： 0.561
#
#
# Bayes第444轮，训练集上准确率： 0.5853333333333334
# Bayes第444轮，测试集上准确率： 0.536
# Bayes第444轮，验证集上准确率： 0.561
#
#
# Bayes第445轮，训练集上准确率： 0.5853333333333334
# Bayes第445轮，测试集上准确率： 0.536
# Bayes第445轮，验证集上准确率： 0.561
#
#
# Bayes第446轮，训练集上准确率： 0.5853333333333334
# Bayes第446轮，测试集上准确率： 0.536
# Bayes第446轮，验证集上准确率： 0.561
#
#
# Bayes第447轮，训练集上准确率： 0.5853333333333334
# Bayes第447轮，测试集上准确率： 0.536
# Bayes第447轮，验证集上准确率： 0.561
#
#
# Bayes第448轮，训练集上准确率： 0.5853333333333334
# Bayes第448轮，测试集上准确率： 0.536
# Bayes第448轮，验证集上准确率： 0.561
#
#
# Bayes第449轮，训练集上准确率： 0.5853333333333334
# Bayes第449轮，测试集上准确率： 0.536
# Bayes第449轮，验证集上准确率： 0.561
#
#
# Bayes第450轮，训练集上准确率： 0.5853333333333334
# Bayes第450轮，测试集上准确率： 0.536
# Bayes第450轮，验证集上准确率： 0.561
#
#
# Bayes第451轮，训练集上准确率： 0.5853333333333334
# Bayes第451轮，测试集上准确率： 0.536
# Bayes第451轮，验证集上准确率： 0.561
#
#
# Bayes第452轮，训练集上准确率： 0.5853333333333334
# Bayes第452轮，测试集上准确率： 0.536
# Bayes第452轮，验证集上准确率： 0.561
#
#
# Bayes第453轮，训练集上准确率： 0.5853333333333334
# Bayes第453轮，测试集上准确率： 0.536
# Bayes第453轮，验证集上准确率： 0.561
#
#
# Bayes第454轮，训练集上准确率： 0.5853333333333334
# Bayes第454轮，测试集上准确率： 0.536
# Bayes第454轮，验证集上准确率： 0.561
#
#
# Bayes第455轮，训练集上准确率： 0.5853333333333334
# Bayes第455轮，测试集上准确率： 0.536
# Bayes第455轮，验证集上准确率： 0.561
#
#
# Bayes第456轮，训练集上准确率： 0.5853333333333334
# Bayes第456轮，测试集上准确率： 0.536
# Bayes第456轮，验证集上准确率： 0.561
#
#
# Bayes第457轮，训练集上准确率： 0.5853333333333334
# Bayes第457轮，测试集上准确率： 0.536
# Bayes第457轮，验证集上准确率： 0.561
#
#
# Bayes第458轮，训练集上准确率： 0.5853333333333334
#
#
# tree第15轮，训练集上准确率： 1.0
# tree第15轮，测试集上准确率： 0.657
# tree第15轮，验证集上准确率： 0.652
#
#
# tree第16轮，训练集上准确率： 1.0
# tree第16轮，测试集上准确率： 0.653
# tree第16轮，验证集上准确率： 0.65
#
#
# tree第17轮，训练集上准确率： 1.0
# tree第17轮，测试集上准确率： 0.647
# tree第17轮，验证集上准确率： 0.654
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 42
#      40 else:
#      41     for epoch in range(1,epochs+1):
# ---> 42         clf = models[model].fit(X_train, Y_train)
#      43         acc = round(clf.score(V_data, V_label), 4)
#      44         print('\n')
#
# File D:\APP\Anaconda\envs\cv\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File D:\APP\Anaconda\envs\cv\lib\site-packages\sklearn\tree\_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ### 1.3机器学习数据分析

# %%
model_name = 'Bayes_best.pt'#KNN_best.pt/SVM_best.pt/tree_best.pt
clf = joblib.load('models/'+model_name)
correct = 0
pre = []
for i in tqdm(range(len(X_test))):
    if clf.predict([X_test[i]])[0] == Y_test[i]:
        correct += 1
    p = correct / (i+1)
    pre.append(p)

wrong = 0
right = 0
rec = []
for i in tqdm(range(len(X_test))):
    if clf.predict([X_test[i]])[0] == Y_test[i] and Y_test[i] == 0:
        right += 1
    if clf.predict([X_test[i]])[0] != Y_test[i] and Y_test[i] == 0:
        wrong += 1
    rec.append(right/(right+wrong+1))

X = [i+1 for i in range(len(X_test))]
Y = [j for j in pre]
Y_rec = [j for j in rec]
plt.plot(X,Y,c='red',label='精确度')
plt.plot(X,Y_rec,c='green',label='召回率')
plt.text(X[-1],Y[-1],s='ACC:%.2f'%Y[-1])
plt.text(X[-1],Y_rec[-1],s='REC:%.2f'%Y_rec[-1])
plt.grid(True, linestyle='--', alpha=0.5)
plt.xlabel('测试集数量/张',fontsize=13)
plt.ylabel('模型在测试集上的准确度和召回率',fontsize=13)
plt.title('Prediction&&Recall@'+model_name,fontsize=15)
plt.legend(loc="lower right")
plt.savefig('figures/'+model_name.split('.')[0]+'.jpg')
plt.show()
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 4436.58it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2314.85it/s]

# %% [markdown]
# ### 1.4机器学习模型部署

# %% [markdown]
# #### 1.4.1本地部署

# %%
LABEL = ['food','non_food']
cap = cv2.VideoCapture(0)                               # 获取摄像头，传入0表示获取系统默认摄像头
cap.open(0)                                             # 打开cap
text = ''
while cap.isOpened():                                   # 无限循环，直到break被触发
    success, frame = cap.read()                         # 获取画面
    if not success:
        print('Error')
        break
    img0 = cv2.resize(img, (24, 24), interpolation=cv2.INTER_CUBIC).flatten()
    text = LABEL[clf.predict([img0])[0]]
    cv2.putText(frame, text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_AA)
    cv2.imshow('111', frame)  # 展示处理后的三通道图像
    if cv2.waitKey(100) in [ord('q'), 27]:  # 按键盘上的q或esc退出（在英文输入法下）
        break
cap.release()  # 关闭摄像头
cv2.destroyAllWindows()  # 关闭图像窗口
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 10
#       8     print('Error')
#       9     break
# ---> 10 img0 = cv2.resize(img, (24, 24), interpolation=cv2.INTER_CUBIC).flatten()
#      11 text = LABEL[clf.predict([img0])[0]]
#      12 cv2.putText(frame, text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_AA)
#
# NameError: name 'img' is not defined

# %% [markdown]
# #### 1.4.2识别图像

# %%
dic_name = 'test/'
pic = [dic_name+i for i in os.listdir(dic_name)]  # dic_name下所有图像路径
for i in tqdm(range(len(pic))):
    path = pic[i]
    img = cv2.imread(path)
    img0 = cv2.resize(img, (24, 24), interpolation=cv2.INTER_CUBIC).flatten()
    text = LABEL[clf.predict([img0])[0]]
    cv2.putText(img, text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_AA)
    cv2.imshow('111',img )  # 展示处理后的三通道图像
    if cv2.waitKey(1000) in [ord('q'), 27]:  # 按键盘上的q或esc退出（在英文输入法下）
        break
cv2.destroyAllWindows()  # 关闭图像窗口
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 dic_name = 'test/'
# ----> 2 pic = [dic_name+i for i in os.listdir(dic_name)]  # dic_name下所有图像路径
#       3 for i in tqdm(range(len(pic))):
#       4     path = pic[i]
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: 'test/'

# %% [markdown]
# #### 1.4.3识别视频

# %%
video_path = 'videos/be787af4c405e2e5c31f60437f2f59b4.mp4'
cap = cv2.VideoCapture(video_path)
while True:
    res, image = cap.read()  # 读出图片。res表示是否读取到图片，image表示读取到的每一帧图片
    if not res:
        print('图片提取结束')
        break
    Img = cv2.resize(image, (24, 24), interpolation=cv2.INTER_CUBIC).flatten()
    text = LABEL[clf.predict([Img])[0]]
    cv2.putText(image, text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_AA)
    cv2.imshow('Gosling can not be more handsome', image)  # 展示处理后的三通道图像
    if cv2.waitKey(100) in [ord('q'), 27]:  # 按键盘上的q或esc退出（在英文输入法下）
        break
cap.release()  # 关闭摄像头
cv2.destroyAllWindows()  # 关闭图像窗口
# Out:
# 图片提取结束

# %% [markdown]
# #### 1.4.4移动识别

# %%
url_path = 'http://192.168.137.35:8081/'   # 视频服务器端口的网址。也可以是在线视频链接
cap = cv2.VideoCapture(url_path)
while True:
    res, image = cap.read()  # 读出图片。res表示是否读取到图片，image表示读取到的每一帧图片
    if not res:
        print('图片提取结束')
        break
    Img = cv2.resize(image, (24, 24), interpolation=cv2.INTER_CUBIC).flatten()
    text = LABEL[clf.predict([Img])[0]]
    cv2.putText(image, text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_AA)
    cv2.imshow('Gosling can not be more handsome', image)  # 展示处理后的三通道图像
    if cv2.waitKey(100) in [ord('q'), 27]:  # 按键盘上的q或esc退出（在英文输入法下）
        break
cap.release()  # 关闭摄像头
cv2.destroyAllWindows()  # 关闭图像窗口

# %% [markdown]
# ## 2.深度学习

# %%
# 导包
import os
import numpy as np
from tqdm import tqdm
from torchvision import datasets
import torch
import torch.nn as nn
from torchvision import models
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
from torch.optim import lr_scheduler
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('device', device)

# %%
# 训练集图像预处理：缩放裁剪、图像增强、转 Tensor、归一化
train_transform = transforms.Compose([transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                     ])

# 测试集图像预处理-RCTN：缩放、裁剪、转 Tensor、归一化
test_transform = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize(
                                         mean=[0.485, 0.456, 0.406],
                                         std=[0.229, 0.224, 0.225])
                                    ])

# %% [markdown]
# ### 2.1深度学习数据处理

# %%
dataset_dir = ''
train_path = os.path.join(dataset_dir, 'training')
test_path = os.path.join(dataset_dir, 'validation')
print('训练集路径', train_path)
print('测试集路径', test_path)
# Out:
# 训练集路径 training
# 测试集路径 validation

# %%
# 载入训练集
train_dataset = datasets.ImageFolder(train_path, train_transform)   #  返回训练数据与标签(标签是文件夹名字）

# 载入测试集
test_dataset = datasets.ImageFolder(test_path, test_transform)

# %%
train_dataset.class_to_idx      # 类别以及对应的标签（自动生成不用自己标注）
# Out:
# {'food': 0, 'non_food': 1}

# %%
idx_to_labels = {y:x for x,y in train_dataset.class_to_idx.items()}
idx_to_labels  # 改变映射关系，因为最终是要根据预测的结果（键）来对应类别（值）
# Out:
# {0: 'food', 1: 'non_food'}

# %%
BATCH_SIZE = 32

# 训练集的数据加载器
train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,  # 每次计算32个样本
                          shuffle=True,  # 在每个epochs计算式打乱数据
                          num_workers=4  # 进程数，相当于在同一时刻计算4*32=108张图片
                          )

# 测试集的数据加载器
test_loader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=4
                         )
"""上述以dataloader为单位将数据喂给模型"""
# Out:
# '上述以dataloader为单位将数据喂给模型'

# %% [markdown]
# ### 2.2深度学习模型训练

# %%
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 2)  # 改变全连接层，映射到n_class维度，这里是二分类，n_class=2，model.fc是整个网络
optimizer = optim.Adam(model.fc.parameters())  # 构造优化器，用来保存当前的状态，并能够根据计算得到的梯度来更新参数
model = model.to(device)  # 这一步很奇妙，就18个字母，就能把这么庞大的，几百层的深度神经网络加到GPU/CPU
criterion = nn.CrossEntropyLoss()

# 训练轮次 Epoch
EPOCHS = 3000
Acc = 0
lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

# %%
for epoch in tqdm(range(EPOCHS)):
    model.train()
    for images, labels in train_loader:  # 获得一个 batch 的数据和标注
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels) # 计算当前 batch 中，每个样本的平均交叉熵损失函数值
        """反向传播三部曲，梯度清零、反向传播，优化迭代"""
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    lr_scheduler.step()

    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in tqdm(test_loader):
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (preds == labels).sum()
    acc = correct / total
    print("acc=",acc)
    if acc > Acc:
        torch.save(model, 'resnet18_best.pth')
        Acc = acc
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]

# %% [markdown]
# ### 2.3深度学习数据分析

# %%
from PIL import Image


def process_frame_pth(img, model):
    model = torch.load(model, map_location=torch.device(device))
    model = model.eval().to(device)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # BGR转RGB
    img_pil = Image.fromarray(img_rgb)  # array 转 PIL
    input_img = test_transform(img_pil).unsqueeze(0).to(device)  # 预处理
    pred_logits = model(input_img)  # 执行前向预测，得到所有类别的 logit 预测分数
    _, pred_ids = torch.max(pred_logits, 1)
    img = np.array(img_pil)  # PIL 转 array
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)  # RGB转BGR
    # 图片，添加的文字，左上角坐标，字体，字体大小，颜色，线宽，线型
    cv2.putText(img, idx_to_labels[int(pred_ids)], (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_AA)
    # return img, idx_to_labels[int(pred_ids)]  # 部署
    return img, idx_to_labels[int(pred_ids)],int(pred_ids)        # 返回标签值

# %%
from tqdm import tqdm
import cv2
model_name = 'resnet18_best.pth'
model_name1 = 'models/'+model_name
# model = torch.load(model_name, map_location=torch.device(device))
img = 'evaluation/'  # 测试集路径
labels = os.listdir(img)
# print(labels)     #['food', 'non_food']
pic_path = []       # 所有测试集图像的路径
X = []              # 测试集向量化的数据
Y = []          # 测试集标签
for label in labels:      # 遍历类别文件夹
    path = img+label
    for pic in os.listdir(path):
        pic_path.append(path+'/'+pic)
        Y.append(labels.index(label))
ID = []
for i in tqdm(range(len(pic_path))):
    pic = pic_path[i]
    im = cv2.imread(pic)
    _,_,a = process_frame_pth(im,model_name1)
    ID.append(a)
print('图像处理完毕！')
# Out:
# 100%|██████████| 1000/1000 [03:22<00:00,  4.94it/s]
# 图像处理完毕！

# %%
correct = 0
pre_pth = []
for i in tqdm(range(len(ID))):
    correct += ID[i]==Y[i]
    pre_pth.append(correct/(i+1))
X_label = [i+1 for i in range(len(ID))]
Y_label = [j for j in pre_pth]
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 488505.01it/s]

# %%
right=0
wrong = 0
rec_pth = []
for i in range(len(ID)):
    if ID[i] == Y[i] and Y[i] == 0:
        right += 1
    if ID[i] != Y[i] and Y[i] == 0:
        wrong += 1
    rec_pth.append(right/(wrong+right+1))
print(rec_pth)
# Out:
# [0.5, 0.6666666666666666, 0.75, 0.8, 0.8333333333333334, 0.8571428571428571, 0.875, 0.8888888888888888, 0.9, 0.9090909090909091, 0.9166666666666666, 0.9230769230769231, 0.9285714285714286, 0.9333333333333333, 0.9375, 0.9411764705882353, 0.9444444444444444, 0.9473684210526315, 0.95, 0.9523809523809523, 0.9545454545454546, 0.9565217391304348, 0.9583333333333334, 0.96, 0.9615384615384616, 0.9629629629629629, 0.9642857142857143, 0.9655172413793104, 0.9666666666666667, 0.967741935483871, 0.96875, 0.9696969696969697, 0.9705882352941176, 0.9714285714285714, 0.9722222222222222, 0.972972972972973, 0.9736842105263158, 0.9743589743589743, 0.975, 0.975609756097561, 0.9761904761904762, 0.9767441860465116, 0.9772727272727273, 0.9777777777777777, 0.9782608695652174, 0.9787234042553191, 0.9791666666666666, 0.9795918367346939, 0.98, 0.9803921568627451, 0.9807692307692307, 0.9811320754716981, 0.9814814814814815, 0.9818181818181818, 0.9821428571428571, 0.9824561403508771, 0.9827586206896551, 0.9830508474576272, 0.9833333333333333, 0.9836065573770492, 0.9838709677419355, 0.9841269841269841, 0.984375, 0.9846153846153847, 0.9848484848484849, 0.9850746268656716, 0.9852941176470589, 0.9855072463768116, 0.9857142857142858, 0.9859154929577465, 0.9861111111111112, 0.9863013698630136, 0.9864864864864865, 0.9866666666666667, 0.9868421052631579, 0.987012987012987, 0.9871794871794872, 0.9873417721518988, 0.9875, 0.9876543209876543, 0.9878048780487805, 0.9879518072289156, 0.9880952380952381, 0.9882352941176471, 0.9883720930232558, 0.9885057471264368, 0.9886363636363636, 0.9887640449438202, 0.9888888888888889, 0.989010989010989, 0.9891304347826086, 0.989247311827957, 0.9893617021276596, 0.9894736842105263, 0.9895833333333334, 0.9896907216494846, 0.9897959183673469, 0.98989898989899, 0.99, 0.9900990099009901, 0.9901960784313726, 0.9902912621359223, 0.9903846153846154, 0.9904761904761905, 0.9905660377358491, 0.9906542056074766, 0.9907407407407407, 0.9908256880733946, 0.990909090909091, 0.990990990990991, 0.9910714285714286, 0.9911504424778761, 0.9912280701754386, 0.991304347826087, 0.9913793103448276, 0.9914529914529915, 0.9915254237288136, 0.9915966386554622, 0.9916666666666667, 0.9917355371900827, 0.9918032786885246, 0.991869918699187, 0.9919354838709677, 0.992, 0.9920634920634921, 0.9921259842519685, 0.9921875, 0.9922480620155039, 0.9923076923076923, 0.9923664122137404, 0.9924242424242424, 0.9924812030075187, 0.9925373134328358, 0.9925925925925926, 0.9926470588235294, 0.9927007299270073, 0.9927536231884058, 0.9928057553956835, 0.9928571428571429, 0.9929078014184397, 0.9929577464788732, 0.993006993006993, 0.9930555555555556, 0.993103448275862, 0.9931506849315068, 0.9931972789115646, 0.9932432432432432, 0.9932885906040269, 0.9933333333333333, 0.9933774834437086, 0.993421052631579, 0.9934640522875817, 0.9935064935064936, 0.9935483870967742, 0.9935897435897436, 0.9936305732484076, 0.9936708860759493, 0.9937106918238994, 0.99375, 0.9937888198757764, 0.9938271604938271, 0.9938650306748467, 0.9939024390243902, 0.9939393939393939, 0.9939759036144579, 0.9940119760479041, 0.9940476190476191, 0.9940828402366864, 0.9941176470588236, 0.9941520467836257, 0.9941860465116279, 0.9942196531791907, 0.9942528735632183, 0.9942857142857143, 0.9943181818181818, 0.9943502824858758, 0.9943820224719101, 0.994413407821229, 0.9944444444444445, 0.994475138121547, 0.9945054945054945, 0.994535519125683, 0.9945652173913043, 0.9945945945945946, 0.9946236559139785, 0.9946524064171123, 0.9946808510638298, 0.9947089947089947, 0.9947368421052631, 0.9947643979057592, 0.9947916666666666, 0.9948186528497409, 0.9948453608247423, 0.9948717948717949, 0.9948979591836735, 0.9949238578680203, 0.9949494949494949, 0.9949748743718593, 0.995, 0.9950248756218906, 0.9900990099009901, 0.9901477832512315, 0.9901960784313726, 0.9902439024390244, 0.9902912621359223, 0.9903381642512077, 0.9903846153846154, 0.9904306220095693, 0.9904761904761905, 0.990521327014218, 0.9905660377358491, 0.9906103286384976, 0.99065420 ...

# %%
plt.plot(X_label,pre_pth,c='red',label='精确度')
plt.plot(X_label,rec_pth,c='green',label='召回率')
plt.text(X_label[-1],pre_pth[-1],s='ACC:%.3f'%pre_pth[-1])
plt.text(X_label[-1],rec_pth[-1],s='REC:%.2f'%rec_pth[-1])
plt.grid(True, linestyle='--', alpha=0.5)
plt.xlabel('测试集数量/张',fontsize=13)
plt.ylabel('模型在测试集上的准确度和召回率',fontsize=13)
plt.title('Prediction&&Recall@'+model_name,fontsize=15)
plt.legend(loc="lower right")
plt.savefig('figures/'+model_name.split('.')[0]+'.jpg')
plt.show()

# %% [markdown]
# ### 2.4深度学习模型部署

# %% [markdown]
# #### 2.4.1本地部署

# %%
cap = cv2.VideoCapture(0)  # 获取摄像头，传入0表示获取系统默认摄像头
cap.open(0)  # 打开cap
text = ''
while cap.isOpened():  # 无限循环，直到break被触发
    success, frame = cap.read()  # 获取画面
    if not success:
        print('Error')
        break
    frame, text,_ = process_frame_pth(frame, model_name1)  ## !!!处理帧函数
    cv2.imshow('Gosling can not be more handsome', frame)  # 展示处理后的三通道图像
    if cv2.waitKey(100) in [ord('q'), 27]:  # 按键盘上的q或esc退出（在英文输入法下）
        break
cap.release()  # 关闭摄像头
cv2.destroyAllWindows()  # 关闭图像窗口

# %% [markdown]
# #### 2.4.2识别图像

# %%
dic_name = 'test/'
pic = [dic_name+i for i in os.listdir(dic_name)]  # dic_name下所有图像路径
for i in tqdm(range(len(pic))):
    path = pic[i]
    img = cv2.imread(path)
    im, text,_ = process_frame_pth(img, model_name1)
    cv2.imshow("Gosling can not be more handsome", im)
    if cv2.waitKey(1000) in [ord('q'), 27]:  # 按键盘上的q或esc退出（在英文输入法下）
        break
cv2.destroyWindow("Predicting")
# Out:
#   0%|          | 1/1000 [00:01<30:09,  1.81s/it]

# %% [markdown]
# #### 2.4.3识别视频

# %%
video_path = 'videos/be787af4c405e2e5c31f60437f2f59b4.mp4'
cap = cv2.VideoCapture(video_path)
while True:
    res, image = cap.read()  # 读出图片。res表示是否读取到图片，image表示读取到的每一帧图片
    if not res:
        print('图片提取结束')
        break
    im, text, _= process_frame_pth(image, model_name1)
    cv2.imshow('Gosling can not be more handsome', im)  # 展示处理后的三通道图像
    if cv2.waitKey(1) in [ord('q'), 27]:  # 按键盘上的q或esc退出（在英文输入法下）
        break
cap.release()  # 关闭摄像头
cv2.destroyAllWindows()  # 关闭图像窗口

# %% [markdown]
# #### 2.4.4移动识别

# %%
url_path = ''
cap = cv2.VideoCapture(url_path)
while True:
    res, image = cap.read()  # 读出图片。res表示是否读取到图片，image表示读取到的每一帧图片
    if not res:
        print('图片提取结束')
        break
    im, text, _= process_frame_pth(image, model_name1)
    cv2.imshow('Gosling can not be more handsome', im)  # 展示处理后的三通道图像
    if cv2.waitKey(1) in [ord('q'), 27]:  # 按键盘上的q或esc退出（在英文输入法下）
        break
cap.release()  # 关闭摄像头
cv2.destroyAllWindows()  # 关闭图像窗口
# Out:
# 图片提取结束
